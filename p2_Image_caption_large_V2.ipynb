# %% [markdown]
# <a href="https://colab.research.google.com/github/R12942159/NTU_DLCV/blob/Hw3/p2_Image_caption_large_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install timm

# %%
import os
import re
import math
import timm
import json
import torch
import collections
import numpy as np
import torch.nn.functional as F
import torchvision.transforms as tr

from PIL import Image
from tqdm import tqdm
from pathlib import Path
from torch import nn, Tensor
from torch.utils.data import DataLoader

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using: {device}")
# Out:
# Using: cuda

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Download dataset and unzip zip file.

# %%
# !gdown 1SUiRrG6zQVtyrVSVh9hOBq5_fX-oV2Lh -O hw3_data.zip # 11rP6KmR5Qwjhx0rfag0b5TZGBTRuPtQR
# !unzip /content/hw3_data.zip

# %% [markdown]
# #### Tokenizer ('<|endoftext|>', 50256) -> 250dim

# %%
class BPETokenizer:

    def __init__(self, encoder_file, vocab_file):
        with open(encoder_file, 'r', encoding='utf-8') as f:
            self.encoder = json.load(f)
        self.decoder = {v:k for k,v in self.encoder.items()}
        with open(vocab_file, 'r', encoding='utf-8') as f:
            vocab = f.read().split('\n')[1:-1]
        self.bpe_ranks = {tuple(line.split()): i for i, line in enumerate(vocab)}
        assert len(self.encoder) == 50257 and len(self.bpe_ranks) == 49999 # len(self.bpe_ranks) == 50000
        bs = list(range(33, 127)) + list(range(161, 256))
        xs = list(range(0, 33)) + list(range(127, 161))
        cs = bs[:] + [2**8 + i for i in range(len(xs))]
        self.byte_encoder = dict(zip(bs + xs, [chr(n) for n in cs]))
        self.byte_decoder = {v:k for k, v in self.byte_encoder.items()}

    def encode(self, text, allowed_special=None):
        tokens = re.findall(r"""<\|endoftext\|>|'s|'t|'re|'ve|'m|'ll|'d| ?""" +
                            r"""\w+| ?\d+| ?[^\s\w\d]+|\s+(?!\S)|\s+""", text, re.UNICODE)
        def translate(token):
            if token == '<|endoftext|>':
                assert allowed_special and token in allowed_special
                return [token]
            word = tuple(''.join(self.byte_encoder[byte] for byte in token.encode('utf-8')))
            while len(word) != 1:
                pairs = set((word[i], word[i+1]) for i in range(len(word)-1))
                bigram = min(pairs, key = lambda pair: self.bpe_ranks.get(pair, float('inf')))
                if bigram not in self.bpe_ranks:
                    break
                a, b = bigram
                new_word = []
                i = 0
                while i < len(word):
                    j = word.index(a, i) if a in word[i:] else len(word)
                    new_word.extend(word[i:j])
                    i = j
                    if i < len(word):
                        j = 2 if i < len(word)-1 and word[i] == a and word[i+1] == b else 1
                        new_word.append(a+b if j == 2 else word[i])
                        i += j
                word = tuple(new_word)
            return word
        return [self.encoder[_] for token in tokens for _ in translate(token)]

    def decode(self, tokens):
        tokens = [self.decoder[token] for token in tokens]
        buffer = bytearray([self.byte_decoder[c] for c in ''.join(tokens)])
        return buffer.decode('utf-8', errors='replace')

# %%
encoding = BPETokenizer('/content/encoder.json', '/content/vocab.bpe')
# prompt = 'a kitchen with a sink and many cooking machines and a pot of food'

# text_embedding_len = 250

# context = encoding.encode(prompt)
# context = [50256] + context + [50256]*(text_embedding_len - len(context) - 1)
# # context
# encoding.decode(context)

# %% [markdown]
# #### Define function

# %%
def json_load(json_path: str):
    with open(json_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

# %%
def caption_with_id(json_path: str) -> list:
    with open(json_path, 'r', encoding='utf-8') as file:
        json_data = json.load(file)
    data = [{'caption': row['caption'], 'image_id': row['image_id']} for row in json_data['annotations']]
    return data

# %%
def id2file_name(json_path: str) -> dict:
    with open(json_path, 'r', encoding='utf-8') as file:
        json_data = json.load(file)
    data = {row['id']: row['file_name'] for row in json_data['images']}
    return data

# %%
encoder_joson_path = '/content/encoder.json'
vocab_bpe_path = '/content/vocab.bpe'
def collate_fn(batch, tokenizer=BPETokenizer(encoder_joson_path, vocab_bpe_path)):
    # Get the individual elements of the batch
    images = [item['img'] for item in batch]
    captions = [item['caption'] for item in batch]
    filenames = [item['filename'] for item in batch]

    # Tokenize captions
    tokenized_captions = [tokenizer.encode(caption) for caption in captions]

    # Pad the vector length into stop token to dimension 250
    text_len = 300 # text_embedding_len
    tokenized_captions_train = [
        [50256] + caption + [50256] * (text_len - len(caption) - 1) for caption in tokenized_captions
    ]
    tokenized_captions_inf = [
        caption + [50256] + [-100] * (text_len - len(caption) - 1) for caption in tokenized_captions
    ]

    # Convert tokenized captions to PyTorch tensors
    tokenized_captions_train = [torch.tensor(caption) for caption in tokenized_captions_train]
    tokenized_captions_inf = [torch.tensor(caption) for caption in tokenized_captions_inf]

    # Create a new batch with tokenized captions
    tokenized_batch = {
        'img': torch.stack(images, dim=0),
        'tokenized_captions_train': torch.stack(tokenized_captions_train, dim=0),
        'filename': filenames,
        'tokenized_captions_inf': torch.stack(tokenized_captions_inf, dim=0),
    }

    return tokenized_batch

# %% [markdown]
# #### Build Dataset

# %%
class ImgCaptionDataset(torch.utils.data.Dataset):
    def __init__(self, img_dir, json_path, transform) -> None:
        super(ImgCaptionDataset, self).__init__()
        self.img_dir = img_dir
        self.transform = transform

        # Connect caption -> image_id -> file_name
        self.caption_with_id = caption_with_id(json_path)
        self.id2file_name = id2file_name(json_path)
    def __len__(self) -> int:
        return len(self.caption_with_id)

    def __getitem__(self, idx):
        caption_id = self.caption_with_id[idx]
        file_name = self.id2file_name[caption_id['image_id']]
        img = Image.open(os.path.join(self.img_dir, file_name)).convert('RGB')
        img = self.transform(img)
        return {'img': img, 'caption': caption_id['caption'], 'filename': os.path.splitext(file_name)[0]}

# %% [markdown]
# #### Build Dataloader

# %%
train_ds = ImgCaptionDataset(
    img_dir='/content/hw3_data/p2_data/images/train',
    json_path='/content/hw3_data/p2_data/train.json',
    transform=tr.Compose([
        tr.Resize(224),
        tr.CenterCrop(224),
        tr.ToTensor(),
        tr.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
)
val_ds = ImgCaptionDataset(
    img_dir='/content/hw3_data/p2_data/images/val',
    json_path='/content/hw3_data/p2_data/val.json',
    transform=tr.Compose([
        tr.Resize(224),
        tr.CenterCrop(224),
        tr.ToTensor(),
        tr.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
)

train_loader = DataLoader(
    train_ds,
    batch_size=16,
    collate_fn=collate_fn,
    shuffle=True,
    num_workers=4,
)
val_loader = DataLoader(
    val_ds,
    batch_size=1,
    collate_fn=collate_fn,
    shuffle=True,
    num_workers=4,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# #### Config

# %%
class Config:

    def __init__(self, checkpoint=None):
        self.n_layer = 12
        self.n_head = 12
        self.n_embd = 768
        self.vocab_size = 50257
        self.block_size = 1024
        self.checkpoint = checkpoint

# %%
cfg = Config(checkpoint='/content/hw3_data/p2_data/decoder_model.bin')

# %% [markdown]
# #### timm's ViT encoder

# %%
# encoder = timm.create_model('vit_large_patch16_224_in21k', pretrained=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/_factory.py:117: UserWarning: Mapping deprecated model name vit_large_patch16_224_in21k to current vit_large_patch16_224.augreg_in21k.
#   model = create_fn(
# model.safetensors:   0%|          | 0.00/1.30G [00:00<?, ?B/s]

# %%
# for batch in train_loader:
#     img = batch['img']
#     break

# %%
# def forward_features(self, x: torch.Tensor) -> torch.Tensor:
#         x = self.patch_embed(x)
#         x = self._pos_embed(x)
#         x = self.patch_drop(x)
#         x = self.norm_pre(x)
# #
#         x = self.blocks(x)
#         for i, block in enumerate(self.blocks()):

#           print(i)
#         x = self.norm(x)
#         return x

# %%
# with torch.no_grad():
#     encoder_out = encoder.patch_embed(img)
#     encoder_out = encoder._pos_embed(encoder_out)
#     encoder_out = encoder.patch_drop(encoder_out)
#     encoder_out = encoder.norm_pre(encoder_out)
#     for i, block in enumerate(encoder.blocks):
#         if i < 23:
#             encoder_out = block(encoder_out)
#             print(i)
#     encoder_out = encoder.norm(encoder_out)

# %%
# encoder_out.size()
# Out:
# torch.Size([16, 197, 1024])

# %% [markdown]
# #### decoder

# %%
class Attention(nn.Module):

    def __init__(self, cfg):
        super().__init__()
        self.c_attn = nn.Linear(cfg.n_embd, 3 * cfg.n_embd)
        self.c_proj = nn.Linear(cfg.n_embd, cfg.n_embd)
        self.n_head = cfg.n_head
        self.n_embd = cfg.n_embd
        size = cfg.block_size
        self.register_buffer('bias', torch.tril(torch.ones(size, size)).view(1, 1, size, size))

    def forward(self, x):
        B, T, C = x.size() # batch, context, embedding
        q, k, v  = self.c_attn(x).split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
        att = att.masked_fill(self.bias[:,:,:T,:T] == 0, float('-inf'))
        att = F.softmax(att, dim=-1)
        return self.c_proj((att @ v).transpose(1, 2).contiguous().view(B, T, C))

class CrossAttention(nn.Module):

    def __init__(self, cfg):
        super().__init__()
        self.multihead_attn = nn.MultiheadAttention(cfg.n_embd, cfg.n_head, batch_first=True)
        self.ln_3 = nn.LayerNorm(cfg.n_embd) # add
        self.ln_4 = nn.LayerNorm(cfg.n_embd) # add
        self.ln_5 = nn.LayerNorm(cfg.n_embd) # add

    def forward(self, query, encoder_out):
        """
        Q is the source from the decoder, K, V are the sources from the encoder.
        Q: (N, L, Eq), where L is the target embedding dim, Eq is embed_dim and batch_first=True.
        {K, V}: (N, L, E{k,v}), where L is the source embedding dim, E{k,v} is {k,v}_dim and batch_first=True.
        """
        query = self.ln_3(query)
        encoder_out1 = self.ln_4(encoder_out)
        encoder_out2 = self.ln_5(encoder_out)
        attn_output, attn_output_weights = self.multihead_attn(query, encoder_out1, encoder_out2)
        return attn_output

class Block(nn.Module):

    def __init__(self, cfg):
        super().__init__()
        self.ln_1 = nn.LayerNorm(cfg.n_embd)
        self.ln_2 = nn.LayerNorm(cfg.n_embd)
        # self.ln_3 = nn.LayerNorm(cfg.n_embd) # add
        # self.ln_4 = nn.LayerNorm(cfg.n_embd) # add
        self.attn = Attention(cfg)
        self.crs_attn = CrossAttention(cfg) # add
        self.mlp = nn.Sequential(collections.OrderedDict([
            ('c_fc', nn.Linear(cfg.n_embd, 4 * cfg.n_embd)),
            ('act', nn.GELU(approximate='tanh')),
            ('c_proj', nn.Linear(4 * cfg.n_embd, cfg.n_embd))
        ]))

    def forward(self, x, encoder_out) -> Tensor: # add
        x = x + self.attn(self.ln_1(x))
        # x = x + self.crs_attn(self.ln_3(x), self.ln_4(encoder_out)) # add
        x = x + self.crs_attn(x, encoder_out) # add
        x = x + self.mlp(self.ln_2(x))
        return x

class Decoder(nn.Module):

    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.block_size = cfg.block_size
        self.transformer = nn.ModuleDict(dict(
            wte = nn.Embedding(cfg.vocab_size, cfg.n_embd), # 文字投影
            wpe = nn.Embedding(cfg.block_size, cfg.n_embd), # position
            h = nn.Sequential(*[Block(cfg) for _ in range(cfg.n_layer)]), # Nx
            ln_f = nn.LayerNorm(cfg.n_embd)
        ))
        self.lm_head = nn.Linear(cfg.n_embd, cfg.vocab_size, bias=False)
        self.transformer.wte.weight = self.lm_head.weight
        # timm's ViT encoder (vit_base_patch16_224_in21k,)
        self.encoder = timm.create_model('vit_large_patch16_224.augreg_in21k', pretrained=True) # vit_large_patch16_224_in21k
        self.linear = nn.Linear(1024, cfg.n_embd) # [16, 197, 1024]
        # load checkpoint
        if self.cfg.checkpoint is not None:
            state_dict = torch.load(self.cfg.checkpoint)
            transposed = [ '.c_attn.weight', '.c_fc.weight', '.c_proj.weight' ]
            for key, value in state_dict.items():
                if any(key.endswith(w) for w in transposed):
                    state_dict[key] = value.t()
            self.transformer.load_state_dict(state_dict, strict=False)

    def forward(self, x: Tensor, img: Tensor) -> Tensor: # add
        x = torch.narrow(x, 1, 0, min(x.size(1), self.block_size))
        pos = torch.arange(x.size()[1], dtype=torch.long, device=x.device).unsqueeze(0)
        x = self.transformer.wte(x) + self.transformer.wpe(pos)
        # encoder veatures
        encoder_out = self.encoder.forward_features(img)
        # encoder_out = self.encoder.patch_embed(img)
        # encoder_out = self.encoder._pos_embed(encoder_out)
        # encoder_out = self.encoder.patch_drop(encoder_out)
        # encoder_out = self.encoder.norm_pre(encoder_out)
        # for i, block in enumerate(self.encoder.blocks):
        #     if i < 23:
        #         encoder_out = block(encoder_out)
        # encoder_out = self.encoder.norm(encoder_out)
        encoder_out = self.linear(encoder_out)
        for block in self.transformer.h:
            x = block(x, encoder_out)
        x = self.lm_head(self.transformer.ln_f(x)) # add
        return x

# %% [markdown]
# #### Decoding test

# %%
# decoder = Decoder(cfg)

# %%
# for batch in train_loader:
#     img = batch['img']
#     tokenized_captions_train = batch['tokenized_captions_train']
#     tokenized_captions_inf = batch['tokenized_captions_inf']
#     break

# %%
# pred = decoder(tokenized_captions_train, img)

# %%
# pred.size(), tokenized_captions_train.size(), img.size(), tokenized_captions_inf.size()

# %%
# encoding.decode(pred[0].argmax(dim=1).tolist())

# %%
# loss_fn = nn.CrossEntropyLoss() # ignore_index=50256

# pred = pred.reshape(-1, 50257)
# tokenized_captions_inf = tokenized_captions_inf.reshape(-1)
# loss_fn(pred, tokenized_captions_inf)

# %% [markdown]
# #### Training

# %%
def training(dataloader, model, loss_fn, optimizer):

    size = len(dataloader.dataset) # number of samples
    num_batches = len(dataloader) # batches per epoch
    epoch_loss = 0

    model.train() # to training mode
    for batch_i, data in enumerate(tqdm(dataloader)):
        data['img'] = data['img'].to(device, non_blocking=True)
        data['tokenized_captions_train'] = data['tokenized_captions_train'].to(device, non_blocking=True)
        data['tokenized_captions_inf'] = data['tokenized_captions_inf'].to(device, non_blocking=True)

        # zero the parameter gradients
        optimizer.zero_grad()

        # Compute prediction loss
        pred = model(data['tokenized_captions_train'], data['img'])
        # reshape to (B, C)
        data['tokenized_captions_inf'] = data['tokenized_captions_inf'].reshape(-1)
        pred = pred.reshape(-1, 50257)
        loss = loss_fn(pred, data['tokenized_captions_inf']) # tokenized captions inf

        # Optimization by gradients
        loss.backward() # backpropagation to compute gradients
        optimizer.step() # update model params

        # write to logs
        epoch_loss += loss.item() # tensor -> python value
    return epoch_loss/num_batches

# %%
def inference(dataloader, model):
    evaluation_dict = {}
    for data in tqdm(dataloader):
        img = data['img'].to(device)
        file_name = data['filename']
        start_token = torch.tensor([[50256]]).to(device)

        for j in range(250):
            with torch.no_grad():
                pred = model(start_token, img)

            out_token = pred.argmax(dim=2)[0][-1]
            start_token = torch.cat((start_token, out_token.unsqueeze(0).unsqueeze(0)), dim=1)
            end_token = torch.sum(start_token[0] == 50256).item()
            if end_token == 2:
                pred_token = start_token[start_token != 50256]
                pred_token = pred_token.tolist()
                pred_caption = encoding.decode(pred_token)
                break

        evaluation_dict[file_name[0]] = pred_caption
        print('\n', 'file name: ', file_name[0], '\caption: ', evaluation_dict[file_name[0]])

    json_string = json.dumps(evaluation_dict, indent=2)  # The indent parameter is optional and adds indentation for better readability
    with open(f'/content/drive/MyDrive/NTU_DLCV/Hw3/p2_output_large/large_lr0.0005_epoch{epoch}_output.json', 'w') as json_file:
        json_file.write(json_string)
    print(f'---------- large params Saved ----------')

# %% [markdown]
# ##### Freeze parameters

# %%
model = Decoder(cfg).to(device)

# Freeze parameters
for name, param in model.named_parameters():
    param.requires_grad=False

# Unfreeze some parameters
for name, params in model.named_parameters():
    params.requires_grad = True if 'crs_attn' in name else params.requires_grad

for params in model.linear.parameters():
    params.requires_grad = True

trainable_weights = [name for name, param in model.named_parameters() if param.requires_grad == True]
print('Total params: ', sum(params.numel() for params in model.parameters() if params.requires_grad))

# list for True
for name, param in model.named_parameters():
    print(f"{name}: {param.requires_grad}")
# Out:
# model.safetensors:   0%|          | 0.00/1.30G [00:00<?, ?B/s]
# Total params:  29190912
# transformer.wte.weight: False
# transformer.wpe.weight: False
# transformer.h.0.ln_1.weight: False
# transformer.h.0.ln_1.bias: False
# transformer.h.0.ln_2.weight: False
# transformer.h.0.ln_2.bias: False
# transformer.h.0.attn.c_attn.weight: False
# transformer.h.0.attn.c_attn.bias: False
# transformer.h.0.attn.c_proj.weight: False
# transformer.h.0.attn.c_proj.bias: False
# transformer.h.0.crs_attn.multihead_attn.in_proj_weight: True
# transformer.h.0.crs_attn.multihead_attn.in_proj_bias: True
# transformer.h.0.crs_attn.multihead_attn.out_proj.weight: True
# transformer.h.0.crs_attn.multihead_attn.out_proj.bias: True
# transformer.h.0.crs_attn.ln_3.weight: True
# transformer.h.0.crs_attn.ln_3.bias: True
# transformer.h.0.crs_attn.ln_4.weight: True
# transformer.h.0.crs_attn.ln_4.bias: True
# transformer.h.0.crs_attn.ln_5.weight: True
# transformer.h.0.crs_attn.ln_5.bias: True
# transformer.h.0.mlp.c_fc.weight: False
# transformer.h.0.mlp.c_fc.bias: False
# transformer.h.0.mlp.c_proj.weight: False
# transformer.h.0.mlp.c_proj.bias: False
# transformer.h.1.ln_1.weight: False
# transformer.h.1.ln_1.bias: False
# transformer.h.1.ln_2.weight: False
# transformer.h.1.ln_2.bias: False
# transformer.h.1.attn.c_attn.weight: False
# transformer.h.1.attn.c_attn.bias: False
# transformer.h.1.attn.c_proj.weight: False
# transformer.h.1.attn.c_proj.bias: False
# transformer.h.1.crs_attn.multihead_attn.in_proj_weight: True
# transformer.h.1.crs_attn.multihead_attn.in_proj_bias: True
# transformer.h.1.crs_attn.multihead_attn.out_proj.weight: True
# transformer.h.1.crs_attn.multihead_attn.out_proj.bias: True
# transformer.h.1.crs_attn.ln_3.weight: True
# transformer.h.1.crs_attn.ln_3.bias: True
# transformer.h.1.crs_attn.ln_4.weight: True
# transformer.h.1.crs_attn.ln_4.bias: True
# transformer.h.1.crs_attn.ln_5.weight: True
# transformer.h.1.crs_attn.ln_5.bias: True
# transformer.h.1.mlp.c_fc.weight: False
# transformer.h.1.mlp.c_fc.bias: False
# transformer.h.1.mlp.c_proj.weight: False
# transformer.h.1.mlp.c_proj.bias: False
# transformer.h.2.ln_1.weight: False
# transformer.h.2.ln_1.bias: False
# transformer.h.2.ln_2.weight: False
# transformer.h.2.ln_2.bias: False
# transformer.h.2.attn.c_attn.weight: False
# transformer.h.2.attn.c_attn.bias: False
# transformer.h.2.attn.c_proj.weight: False
# transformer.h.2.attn.c_proj.bias: False
# transformer.h.2.crs_attn.multihead_attn.in_proj_weight: True
# transformer.h.2.crs_attn.multihead_attn.in_proj_bias: True
# transformer.h.2.crs_attn.multihead_attn.out_proj.weight: True
# transformer.h.2.crs_attn.multihead_attn.out_proj.bias: True
# transformer.h.2.crs_attn.ln_3.weight: True
# transformer.h.2.crs_attn.ln_3.bias: True
# transformer.h.2.crs_attn.ln_4.weight: True
# transformer.h.2.crs_attn.ln_4.bias: True
# transformer.h.2.crs_attn.ln_5.weight: True
# transformer.h.2.crs_attn.ln_5.bias: True
# transformer.h.2.mlp.c_fc.weight: False
# transformer.h.2.mlp.c_fc.bias: False
# transformer.h.2.mlp.c_proj.weight: False
# transformer.h.2.mlp.c_proj.bias: False
# transformer.h.3.ln_1.weight: False
# transformer.h.3.ln_1.bias: False
# transformer.h.3.ln_2.weight: False
# transformer.h.3.ln_2.bias: False
# transformer.h.3.attn.c_attn.weight: False
# transformer.h.3.attn.c_attn.bias: False
# transformer.h.3.attn.c_proj.weight: False
# transformer.h.3.attn.c_proj.bias: False
# transformer.h.3.crs_attn.multihead_attn.in_proj_weight: True
# transformer.h.3.crs_attn.multihead_attn.in_proj_bias: True
# transformer.h.3.crs_attn.multihead_attn.out_proj.weight: True
# transformer.h.3.crs_attn.multihead_attn.out_proj.bias: True
# transformer.h.3.crs_attn.ln_3.weight: True
# transformer.h.3.crs_attn.ln_3.bias: True
# transformer.h.3.crs_attn.ln_4.weight: True
# transformer.h.3.crs_attn.ln_4.bias: True
# transformer.h.3.crs_attn.ln_5.weight: True
# transformer.h.3.crs_attn.ln_5.bias: True
# transformer.h.3.mlp.c_fc.weight: False
# transformer.h.3.mlp.c_fc.bias: False
# transformer.h.3.mlp.c_proj.weight: False
# transformer.h.3.mlp.c_proj.bias: False
# transformer.h.4.ln_1.weight: False
# transformer.h.4.ln_1.bias: False
# transformer.h.4.ln_2.weight: False
# transformer.h.4.ln_2.bias: False
# transformer.h.4.attn.c_attn.weight: False
# transformer.h.4.attn.c_attn.bias: False
# transformer.h.4.attn.c_proj.weight: False
# transformer.h.4.attn.c_proj.bias: False
# transformer.h.4.crs_attn.multihead_attn.in_proj_weight: True
# transformer.h.4.crs_attn.multihead_attn.in_proj_bias: True
# transformer.h.4.crs_attn.multihead_attn.out_proj.weight: True
# transformer.h.4.crs_attn.multihead_attn.out_proj.bias: True
# transformer.h.4.crs_attn.ln_3.weight: True
# transformer.h.4.crs_attn.ln_3.bias: True
# transformer.h.4.crs_attn.ln_4.weight: True
# transformer.h.4.crs_attn.ln_4.bias: True
# transformer.h.4.crs_attn.ln_5.weight: True
# transformer.h.4.crs_attn.ln_5.bias: True
# transformer.h.4.mlp.c_fc.weight: False
# transformer.h.4.mlp.c_fc.bias: False
# transformer.h.4.mlp.c_proj.weight: False
# transformer.h.4.mlp.c_proj.bias: False
# transformer.h.5.ln_1.weight: False
# transformer.h.5.ln_1.bias: False
# transformer.h.5.ln_2.weight: False
# transformer.h.5.ln_2.bias: False
# transformer.h.5.attn.c_attn.weight: False
# transformer.h.5.attn.c_attn.bias: False
# transformer.h.5.attn.c_proj.weight: False
# transformer.h.5.attn.c_proj.bias: False
# transformer.h.5.crs_attn.multihead_attn.in_proj_weight: True
# transformer.h.5.crs_attn.multihead_attn.in_proj_bias: True
# transformer.h.5.crs_attn.multihead_attn.out_proj.weight: True
# transformer.h.5.crs_attn.multihead_attn.out_proj.bias: True
# transformer.h.5.crs_attn.ln_3.weight: True
# transformer.h.5.crs_attn.ln_3.bias: True
# transformer.h.5.crs_attn.ln_4.weight: True
# transformer.h.5.crs_attn.ln_4.bias: True
# transformer.h.5.crs_attn.ln_5.weight: True
# transformer.h.5.crs_attn.ln_5.bias: True
# transformer.h.5.mlp.c_fc.weight: False
# transformer.h.5.mlp.c_fc.bias: False
# transformer.h.5.mlp.c_proj.weight: False
# transformer.h.5.mlp.c_proj.bias: False
# transformer.h.6.ln_1.weight: False
# transformer.h.6.ln_1.bias: False
# transformer.h.6.ln_2.weight: False
# transformer.h.6.ln_2.bias: False
# transformer.h.6.attn.c_attn.weight: False
# transformer.h.6.attn.c_attn.bias: False
# transformer.h.6.attn.c_proj.weight: False
# transformer.h.6.attn.c_proj.bias: False
# transformer.h.6.crs_attn.multihead_attn.in_proj_weight: True
# transformer.h.6.crs_attn.multihead_attn.in_proj_bias: True
# transformer.h.6.crs_attn.multihead_attn.out_proj.weight: True
# transformer.h.6.crs_attn.multihead_attn.out_proj.bias: True
# transformer.h.6.crs_attn.ln_3.weight: True
# transformer.h.6.crs_attn.ln_3.bias: True
# transformer.h.6.crs_attn.ln_4.weight: True
# transformer.h.6.crs_attn.ln_4.bias: True
# transformer.h.6.crs_attn.ln_5.weight: True
# transformer.h.6.crs_attn.ln_5.bias: True
# transformer.h.6.mlp.c_fc.weight: False
# transformer.h.6.mlp.c_fc.bias: False
# transformer.h.6.mlp.c_proj.weight: False
# transformer.h.6.mlp.c_proj.bias: False
# transformer.h.7.ln_1.weight: False
# transformer.h.7.ln_1.bias: False
# transformer.h.7.ln_2.weight: False
# transformer.h.7.ln_2.bias: False
# transformer.h.7.attn.c_attn.weight: False
# transformer.h.7.attn.c_attn.bias: False
# transformer.h.7.attn.c_proj.weight: False
# transformer.h.7.attn.c_proj.bias: False
# transformer.h.7.crs_attn.multihead_attn.in_proj_weight: True
# transformer.h.7.crs_attn.multihead_attn.in_proj_bias: True
# transformer.h.7.crs_attn.multihead_attn.out_proj.weight: True
# transformer.h.7.crs_attn.multihead_attn.out_proj.bias: True
# transformer.h.7.crs_attn.ln_3.weight: True
# transformer.h.7.crs_attn.ln_3.bias: True
# transformer.h.7.crs_attn.ln_4.weight: True
# transformer.h.7.crs_attn.ln_4.bias: True
# transformer.h.7.crs_attn.ln_5.weight: True
# transformer.h.7.crs_attn.ln_5.bias: True
# transformer.h.7.mlp.c_fc.weight: False
# transformer.h.7.mlp.c_fc.bias: False
# transformer.h.7.mlp.c_proj.weight: False
# transformer.h.7.mlp.c_proj.bias: False
# transformer.h.8.ln_1.weight: False
# transformer.h.8.ln_1.bias: False
# transformer.h.8.ln_2.weight: False
# transformer.h.8.ln_2.bias: False
# transformer.h.8.attn.c_attn.weight: False
# transformer.h.8.attn.c_attn.bias: False
# transformer.h.8.attn.c_proj.weight: False
# transformer.h.8.attn.c_proj.bias: False
# transformer.h.8.crs_attn.multihead_attn.in_proj_weight: True
# transformer.h.8.crs_attn.multihead_attn.in_proj_bias: True
# transformer.h.8.crs_attn.multihead_attn.out_proj.weight: True
# transformer.h.8.crs_attn.multihead_attn.out_proj.bias: True
# transformer.h.8.crs_attn.ln_3.weight: True
# transformer.h.8.crs_attn.ln_3.bias: True
# transformer.h.8.crs_attn.ln_4.weight: True
# transformer.h.8.crs_attn.ln_4.bias: True
# transformer.h.8.crs_attn.ln_5.weight: True
# transformer.h.8.crs_attn.ln_5.bias: True
# transformer.h.8.mlp.c_fc.weight: False
# transformer.h.8.mlp.c_fc.bias: False
# transformer.h.8.mlp.c_proj.weight: False
# transformer.h.8.mlp.c_proj.bias: False
# transformer.h.9.ln_1.weight: False
# transformer.h.9.ln_1.bias: False
# transformer.h.9.ln_2.weight: False
# transformer.h.9.ln_2.bias: False
# transformer.h.9.attn.c_attn.weight: False
# transformer.h.9.attn.c_attn.bias: False
# transformer.h.9.attn.c_proj.weight: False
# transformer.h.9.attn.c_proj.bias: False
# transformer.h.9.crs_attn.multihead_attn.in_proj_weight: True
# transformer.h.9.crs_attn.multihead_attn.in_proj_bias: True
# transformer.h.9.crs_attn.multihead_attn.out_proj.weight: True
# transformer.h.9.crs_attn.multihead_attn.out_proj.bias: True
# transformer.h.9.crs_attn.ln_3.weight: True
# transformer.h.9.crs_attn.ln_3.bias: True
# transformer.h.9.crs_attn.ln_4.weight: True
# transformer.h.9.crs_attn.ln_4.bias: True
# transformer.h.9.crs_attn.ln_5.weight: True
# transformer.h.9.crs_attn.ln_5.bias: True
# transformer.h.9.mlp.c_fc.weight: False
# transformer.h.9.mlp.c_fc.bias: False
# transformer.h.9.mlp.c_proj.weight: False
# transformer.h.9.mlp.c_proj.bias: False
# transformer.h.10.ln_1.weight: False
# transformer.h.10.ln_1.bias: False
# transformer.h.10.ln_2.weight: False
# transformer.h.10.ln_2.bias: False
# transformer.h.10.attn.c_attn.weight: False
# transformer.h.10.attn.c_attn.bias: False
# transformer.h.10.attn.c_proj.weight: False
# transformer.h.10.attn.c_proj.bias: False
# transformer.h.10.crs_attn.multihead_attn.in_proj_weight: True
# transformer.h.10.crs_attn.multihead_attn.in_proj_bias: True
# transformer.h.10.crs_attn.multihead_attn.out_proj.weight: True
# transformer.h.10.crs_attn.multihead_attn.out_proj.bias: True
# transformer.h.10.crs_attn.ln_3.weight: True
# transformer.h.10.crs_attn.ln_3.bias: True
# transformer.h.10.crs_attn.ln_4.weight: True
# transformer.h.10.crs_attn.ln_4.bias: True
# transformer.h.10.crs_attn.ln_5.weight: True
# transformer.h.10.crs_attn.ln_5.bias: True
# transformer.h.10.mlp.c_fc.weight: False
# transformer.h.10.mlp.c_fc.bias: False
# transformer.h.10.mlp.c_proj.weight: False
# transformer.h.10.mlp.c_proj.bias: False
# transformer.h.11.ln_1.weight: False
# transformer.h.11.ln_1.bias: False
# transformer.h.11.ln_2.weight: False
# transformer.h.11.ln_2.bias: False
# transformer.h.11.attn.c_attn.weight: False
# transformer.h.11.attn.c_attn.bias: False
# transformer.h.11.attn.c_proj.weight: False
# transformer.h.11.attn.c_proj.bias: False
# transformer.h.11.crs_attn.multihead_attn.in_proj_weight: True
# transformer.h.11.crs_attn.multihead_attn.in_proj_bias: True
# transformer.h.11.crs_attn.multihead_attn.out_proj.weight: True
# transformer.h.11.crs_attn.multihead_attn.out_proj.bias: True
# transformer.h.11.crs_attn.ln_3.weight: True
# transformer.h.11.crs_attn.ln_3.bias: True
# transformer.h.11.crs_attn.ln_4.weight: True
# transformer.h.11.crs_attn.ln_4.bias: True
# transformer.h.11.crs_attn.ln_5.weight: True
# transformer.h.11.crs_attn.ln_5.bias: True
# transformer.h.11.mlp.c_fc.weight: False
# transformer.h.11.mlp.c_fc.bias: False
# transformer.h.11.mlp.c_proj.weight: False
# transformer.h.11.mlp.c_proj.bias: False
# transformer.ln_f.weight: False
# transformer.ln_f.bias: False
# encoder.cls_token: False
# encoder.pos_embed: False
# encoder.patch_embed.proj.weight: False
# encoder.patch_embed.proj.bias: False
# encoder.blocks.0.norm1.weight: False
# encoder.blocks.0.norm1.bias: False
# encoder.blocks.0.attn.qkv.weight: False
# encoder.blocks.0.attn.qkv.bias: False
# encoder.blocks.0.attn.proj.weight: False
# encoder.blocks.0.attn.proj.bias: False
# encoder.blocks.0.norm2.weight: False
# encoder.blocks.0.norm2.bias: False
# encoder.blocks.0.mlp.fc1.weight: False
# encoder.blocks.0.mlp.fc1.bias: False
# encoder.blocks.0.mlp.fc2.weight: False
# encoder.blocks.0.mlp.fc2.bias: False
# encoder.blocks.1.norm1.weight: False
# encoder.blocks.1.norm1.bias: False
# encoder.blocks.1.attn.qkv.weight: False
# encoder.blocks.1.attn.qkv.bias: False
# encoder.blocks.1.attn.proj.weight: False
# encoder.blocks.1.attn.proj.bias: False
# encoder.blocks.1.norm2.weight: False
# encoder.blocks.1.norm2.bias: False
# encoder.blocks.1.mlp.fc1.weight: False
# encoder.blocks.1.mlp.fc1.bias: False
# encoder.blocks.1.mlp.fc2.weight: False
# encoder.blocks.1.mlp.fc2.bias: False
# encoder.blocks.2.norm1.weight: False
# encoder.blocks.2.norm1.bias: False
# encoder.blocks.2.attn.qkv.weight: False
# encoder.blocks.2.attn.qkv.bias: False
# encoder.blocks.2.attn.proj.weight: False
# encoder.blocks.2.attn.proj.bias: False
# encoder.blocks.2.norm2.weight: False
# encoder.blocks.2.norm2.bias: False
# encoder.blocks.2.mlp.fc1.weight: False
# encoder.blocks.2.mlp.fc1.bias: False
# encoder.blocks.2.mlp.fc2.weight: False
# encoder.blocks.2.mlp.fc2.bias: False
# encoder.blocks.3.norm1.weight: False
# encoder.blocks.3.norm1.bias: False
# encoder.blocks.3.attn.qkv.weight: False
# encoder.blocks.3.attn.qkv.bias: False
# encoder.blocks.3.attn.proj.weight: False
# encoder.blocks.3.attn.proj.bias: False
# encoder.blocks.3.norm2.weight: False
# encoder.blocks.3.norm2.bias: False
# encoder.blocks.3.mlp.fc1.weight: False
# encoder.blocks.3.mlp.fc1.bias: False
# encoder.blocks.3.mlp.fc2.weight: False
# encoder.blocks.3.mlp.fc2.bias: False
# encoder.blocks.4.norm1.weight: False
# encoder.blocks.4.norm1.bias: False
# encoder.blocks.4.attn.qkv.weight: False
# encoder.blocks.4.attn.qkv.bias: False
# encoder.blocks.4.attn.proj.weight: False
# encoder.blocks.4.attn.proj.bias: False
# encoder.blocks.4.norm2.weight: False
# encoder.blocks.4.norm2.bias: False
# encoder.blocks.4.mlp.fc1.weight: False
# encoder.blocks.4.mlp.fc1.bias: False
# encoder.blocks.4.mlp.fc2.weight: False
# encoder.blocks.4.mlp.fc2.bias: False
# encoder.blocks.5.norm1.weight: False
# encoder.blocks.5.norm1.bias: False
# encoder.blocks.5.attn.qkv.weight: False
# encoder.blocks.5.attn.qkv.bias: False
# encoder.blocks.5.attn.proj.weight: False
# encoder.blocks.5.attn.proj.bias: False
# encoder.blocks.5.norm2.weight: False
# encoder.blocks.5.norm2.bias: False
# encoder.blocks.5.mlp.fc1.weight: False
# encoder.blocks.5.mlp.fc1.bias: False
# encoder.blocks.5.mlp.fc2.weight: False
# encoder.blocks.5.mlp.fc2.bias: False
# encoder.blocks.6.norm1.weight: False
# encoder.blocks.6.norm1.bias: False
# encoder.blocks.6.attn.qkv.weight: False
# encoder.blocks.6.attn.qkv.bias: False
# encoder.blocks.6.attn.proj.weight: False
# encoder.blocks.6.attn.proj.bias: False
# encoder.blocks.6.norm2.weight: False
# encoder.blocks.6.norm2.bias: False
# encoder.blocks.6.mlp.fc1.weight: False
# encoder.blocks.6.mlp.fc1.bias: False
# encoder.blocks.6.mlp.fc2.weight: False
# encoder.blocks.6.mlp.fc2.bias: False
# encoder.blocks.7.norm1.weight: False
# encoder.blocks.7.norm1.bias: False
# encoder.blocks.7.attn.qkv.weight: False
# encoder.blocks.7.attn.qkv.bias: False
# encoder.blocks.7.attn.proj.weight: False
# encoder.blocks.7.attn.proj.bias: False
# encoder.blocks.7.norm2.weight: False
# encoder.blocks.7.norm2.bias: False
# encoder.blocks.7.mlp.fc1.weight: False
# encoder.blocks.7.mlp.fc1.bias: False
# encoder.blocks.7.mlp.fc2.weight: False
# encoder.blocks.7.mlp.fc2.bias: False
# encoder.blocks.8.norm1.weight: False
# encoder.blocks.8.norm1.bias: False
# encoder.blocks.8.attn.qkv.weight: False
# encoder.blocks.8.attn.qkv.bias: False
# encoder.blocks.8.attn.proj.weight: False
# encoder.blocks.8.attn.proj.bias: False
# encoder.blocks.8.norm2.weight: False
# encoder.blocks.8.norm2.bias: False
# encoder.blocks.8.mlp.fc1.weight: False
# encoder.blocks.8.mlp.fc1.bias: False
# encoder.blocks.8.mlp.fc2.weight: False
# encoder.blocks.8.mlp.fc2.bias: False
# encoder.blocks.9.norm1.weight: False
# encoder.blocks.9.norm1.bias: False
# encoder.blocks.9.attn.qkv.weight: False
# encoder.blocks.9.attn.qkv.bias: False
# encoder.blocks.9.attn.proj.weight: False
# encoder.blocks.9.attn.proj.bias: False
# encoder.blocks.9.norm2.weight: False
# encoder.blocks.9.norm2.bias: False
# encoder.blocks.9.mlp.fc1.weight: False
# encoder.blocks.9.mlp.fc1.bias: False
# encoder.blocks.9.mlp.fc2.weight: False
# encoder.blocks.9.mlp.fc2.bias: False
# encoder.blocks.10.norm1.weight: False
# encoder.blocks.10.norm1.bias: False
# encoder.blocks.10.attn.qkv.weight: False
# encoder.blocks.10.attn.qkv.bias: False
# encoder.blocks.10.attn.proj.weight: False
# encoder.blocks.10.attn.proj.bias: False
# encoder.blocks.10.norm2.weight: False
# encoder.blocks.10.norm2.bias: False
# encoder.blocks.10.mlp.fc1.weight: False
# encoder.blocks.10.mlp.fc1.bias: False
# encoder.blocks.10.mlp.fc2.weight: False
# encoder.blocks.10.mlp.fc2.bias: False
# encoder.blocks.11.norm1.weight: False
# encoder.blocks.11.norm1.bias: False
# encoder.blocks.11.attn.qkv.weight: False
# encoder.blocks.11.attn.qkv.bias: False
# encoder.blocks.11.attn.proj.weight: False
# encoder.blocks.11.attn.proj.bias: False
# encoder.blocks.11.norm2.weight: False
# encoder.blocks.11.norm2.bias: False
# encoder.blocks.11.mlp.fc1.weight: False
# encoder.blocks.11.mlp.fc1.bias: False
# encoder.blocks.11.mlp.fc2.weight: False
# encoder.blocks.11.mlp.fc2.bias: False
# encoder.blocks.12.norm1.weight: False
# encoder.blocks.12.norm1.bias: False
# encoder.blocks.12.attn.qkv.weight: False
# encoder.blocks.12.attn.qkv.bias: False
# encoder.blocks.12.attn.proj.weight: False
# encoder.blocks.12.attn.proj.bias: False
# encoder.blocks.12.norm2.weight: False
# encoder.blocks.12.norm2.bias: False
# encoder.blocks.12.mlp.fc1.weight: False
# encoder.blocks.12.mlp.fc1.bias: False
# encoder.blocks.12.mlp.fc2.weight: False
# encoder.blocks.12.mlp.fc2.bias: False
# encoder.blocks.13.norm1.weight: False
# encoder.blocks.13.norm1.bias: False
# encoder.blocks.13.attn.qkv.weight: False
# encoder.blocks.13.attn.qkv.bias: False
# encoder.blocks.13.attn.proj.weight: False
# encoder.blocks.13.attn.proj.bias: False
# encoder.blocks.13.norm2.weight: False
# encoder.blocks.13.norm2.bias: False
# encoder.blocks.13.mlp.fc1.weight: False
# encoder.blocks.13.mlp.fc1.bias: False
# encoder.blocks.13.mlp.fc2.weight: False
# encoder.blocks.13.mlp.fc2.bias: False
# encoder.blocks.14.norm1.weight: False
# encoder.blocks.14.norm1.bias: False
# encoder.blocks.14.attn.qkv.weight: False
# encoder.blocks.14.attn.qkv.bias: False
# encoder.blocks.14.attn.proj.weight: False
# encoder.blocks.14.attn.proj.bias: False
# encoder.blocks.14.norm2.weight: False
# encoder.blocks.14.norm2.bias: False
# encoder.blocks.14.mlp.fc1.weight: False
# encoder.blocks.14.mlp.fc1.bias: False
# encoder.blocks.14.mlp.fc2.weight: False
# encoder.blocks.14.mlp.fc2.bias: False
# encoder.blocks.15.norm1.weight: False
# encoder.blocks.15.norm1.bias: False
# encoder.blocks.15.attn.qkv.weight: False
# encoder.blocks.15.attn.qkv.bias: False
# encoder.blocks.15.attn.proj.weight: False
# encoder.blocks.15.attn.proj.bias: False
# encoder.blocks.15.norm2.weight: False
# encoder.blocks.15.norm2.bias: False
# encoder.blocks.15.mlp.fc1.weight: False
# encoder.blocks.15.mlp.fc1.bias: False
# encoder.blocks.15.mlp.fc2.weight: False
# encoder.blocks.15.mlp.fc2.bias: False
# encoder.blocks.16.norm1.weight: False
# encoder.blocks.16.norm1.bias: False
# encoder.blocks.16.attn.qkv.weight: False
# encoder.blocks.16.attn.qkv.bias: False
# encoder.blocks.16.attn.proj.weight: False
# encoder.blocks.16.attn.proj.bias: False
# encoder.blocks.16.norm2.weight: False
# encoder.blocks.16.norm2.bias: False
# encoder.blocks.16.mlp.fc1.weight: False
# encoder.blocks.16.mlp.fc1.bias: False
# encoder.blocks.16.mlp.fc2.weight: False
# encoder.blocks.16.mlp.fc2.bias: False
# encoder.blocks.17.norm1.weight: False
# encoder.blocks.17.norm1.bias: False
# encoder.blocks.17.attn.qkv.weight: False
# encoder.blocks.17.attn.qkv.bias: False
# encoder.blocks.17.attn.proj.weight: False
# encoder.blocks.17.attn.proj.bias: False
# encoder.blocks.17.norm2.weight: False
# encoder.blocks.17.norm2.bias: False
# encoder.blocks.17.mlp.fc1.weight: False
# encoder.blocks.17.mlp.fc1.bias: False
# encoder.blocks.17.mlp.fc2.weight: False
# encoder.blocks.17.mlp.fc2.bias: False
# encoder.blocks.18.norm1.weight: False
# encoder.blocks.18.norm1.bias: False
# encoder.blocks.18.attn.qkv.weight: False
# encoder.blocks.18.attn.qkv.bias: False
# encoder.blocks.18.attn.proj.weight: False
# encoder.blocks.18.attn.proj.bias: False
# encoder.blocks.18.norm2.weight: False
# encoder.blocks.18.norm2.bias: False
# encoder.blocks.18.mlp.fc1.weight: False
# encoder.blocks.18.mlp.fc1.bias: False
# encoder.blocks.18.mlp.fc2.weight: False
# encoder.blocks.18.mlp.fc2.bias: False
# encoder.blocks.19.norm1.weight: False
# encoder.blocks.19.norm1.bias: False
# encoder.blocks.19.attn.qkv.weight: False
# encoder.blocks.19.attn.qkv.bias: False
# encoder.blocks.19.attn.proj.weight: False
# encoder.blocks.19.attn.proj.bias: False
# encoder.blocks.19.norm2.weight: False
# encoder.blocks.19.norm2.bias: False
# encoder.blocks.19.mlp.fc1.weight: False
# encoder.blocks.19.mlp.fc1.bias: False
# encoder.blocks.19.mlp.fc2.weight: False
# encoder.blocks.19.mlp.fc2.bias: False
# encoder.blocks.20.norm1.weight: False
# encoder.blocks.20.norm1.bias: False
# encoder.blocks.20.attn.qkv.weight: False
# encoder.blocks.20.attn.qkv.bias: False
# encoder.blocks.20.attn.proj.weight: False
# encoder.blocks.20.attn.proj.bias: False
# encoder.blocks.20.norm2.weight: False
# encoder.blocks.20.norm2.bias: False
# encoder.blocks.20.mlp.fc1.weight: False
# encoder.blocks.20.mlp.fc1.bias: False
# encoder.blocks.20.mlp.fc2.weight: False
# encoder.blocks.20.mlp.fc2.bias: False
# encoder.blocks.21.norm1.weight: False
# encoder.blocks.21.norm1.bias: False
# encoder.blocks.21.attn.qkv.weight: False
# encoder.blocks.21.attn.qkv.bias: False
# encoder.blocks.21.attn.proj.weight: False
# encoder.blocks.21.attn.proj.bias: False
# encoder.blocks.21.norm2.weight: False
# encoder.blocks.21.norm2.bias: False
# encoder.blocks.21.mlp.fc1.weight: False
# encoder.blocks.21.mlp.fc1.bias: False
# encoder.blocks.21.mlp.fc2.weight: False
# encoder.blocks.21.mlp.fc2.bias: False
# encoder.blocks.22.norm1.weight: False
# encoder.blocks.22.norm1.bias: False
# encoder.blocks.22.attn.qkv.weight: False
# encoder.blocks.22.attn.qkv.bias: False
# encoder.blocks.22.attn.proj.weight: False
# encoder.blocks.22.attn.proj.bias: False
# encoder.blocks.22.norm2.weight: False
# encoder.blocks.22.norm2.bias: False
# encoder.blocks.22.mlp.fc1.weight: False
# encoder.blocks.22.mlp.fc1.bias: False
# encoder.blocks.22.mlp.fc2.weight: False
# encoder.blocks.22.mlp.fc2.bias: False
# encoder.blocks.23.norm1.weight: False
# encoder.blocks.23.norm1.bias: False
# encoder.blocks.23.attn.qkv.weight: False
# encoder.blocks.23.attn.qkv.bias: False
# encoder.blocks.23.attn.proj.weight: False
# encoder.blocks.23.attn.proj.bias: False
# encoder.blocks.23.norm2.weight: False
# encoder.blocks.23.norm2.bias: False
# encoder.blocks.23.mlp.fc1.weight: False
# encoder.blocks.23.mlp.fc1.bias: False
# encoder.blocks.23.mlp.fc2.weight: False
# encoder.blocks.23.mlp.fc2.bias: False
# encoder.norm.weight: False
# encoder.norm.bias: False
# encoder.head.weight: False
# encoder.head.bias: False
# linear.weight: True
# linear.bias: True

# %% [markdown]
# ##### Training

# %%
EPOCHS = 7
lr=5e-4
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# logs
logs = {
    'train_loss': []
}

for epoch in tqdm(range(EPOCHS)):
    train_loss = training(train_loader, model, loss_fn, optimizer)
    # inference(val_loader, model)

    print(f'EPOCH: {epoch:04d} \train_loss: {train_loss:.4f}')

    logs['train_loss'].append(train_loss)

    # Save model
    save_weights = {k: v for k, v in model.state_dict().items() if k in trainable_weights}
    torch.save(save_weights, f'/content/drive/MyDrive/NTU_DLCV/Hw3/p2_ckpt_large/largeV2_lr{lr}_epoch{epoch}_{train_loss:.4f}.pth')
    print(f'---------- epoch{epoch}: Model Save ----------')
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/3316 [00:00<?, ?it/s]
#   0%|          | 1/3316 [00:08<7:31:18,  8.17s/it]
#   0%|          | 2/3316 [00:08<3:21:59,  3.66s/it]
#   0%|          | 3/3316 [00:09<2:01:59,  2.21s/it]
#   0%|          | 4/3316 [00:09<1:24:43,  1.54s/it]
#   0%|          | 5/3316 [00:10<1:04:09,  1.16s/it]
#   0%|          | 6/3316 [00:10<51:37,  1.07it/s]
#   0%|          | 7/3316 [00:11<43:32,  1.27it/s]
#   0%|          | 8/3316 [00:11<38:13,  1.44it/s]
#   0%|          | 9/3316 [00:12<34:54,  1.58it/s]
#   0%|          | 10/3316 [00:12<32:38,  1.69it/s]
#   0%|          | 11/3316 [00:13<30:59,  1.78it/s]
#   0%|          | 12/3316 [00:13<29:50,  1.85it/s]
#   0%|          | 13/3316 [00:14<28:58,  1.90it/s]
#   0%|          | 14/3316 [00:14<28:27,  1.93it/s]
#   0%|          | 15/3316 [00:15<28:09,  1.95it/s]
#   0%|          | 16/3316 [00:15<27:57,  1.97it/s]
#   1%|          | 17/3316 [00:16<28:00,  1.96it/s]
#   1%|          | 18/3316 [00:16<28:13,  1.95it/s]
#   1%|          | 19/3316 [00:17<28:16,  1.94it/s]
#   1%|          | 20/3316 [00:17<28:14,  1.95it/s]
#   1%|          | 21/3316 [00:18<28:00,  1.96it/s]
#   1%|          | 22/3316 [00:18<27:46,  1.98it/s]
#   1%|          | 23/3316 [00:19<27:34,  1.99it/s]
#   1%|          | 24/3316 [00:19<27:26,  2.00it/s]
#   1%|          | 25/3316 [00:20<27:14,  2.01it/s]
#   1%|          | 26/3316 [00:20<27:12,  2.02it/s]
#   1%|          | 27/3316 [00:21<27:14,  2.01it/s]
#   1%|          | 28/3316 [00:21<27:16,  2.01it/s]
#   1%|          | 29/3316 [00:22<27:10,  2.02it/s]
#   1%|          | 30/3316 [00:22<27:09,  2.02it/s]
#   1%|          | 31/3316 [00:23<27:10,  2.01it/s]
#   1%|          | 32/3316 [00:23<27:11,  2.01it/s]
#   1%|          | 33/3316 [00:24<27:06,  2.02it/s]
#   1%|          | 34/3316 [00:24<27:04,  2.02it/s]
#   1%|          | 35/3316 [00:25<27:04,  2.02it/s]
#   1%|          | 36/3316 [00:25<27:05,  2.02it/s]
#   1%|          | 37/3316 [00:26<27:00,  2.02it/s]
#   1%|          | 38/3316 [00:26<27:09,  2.01it/s]
#   1%|          | 39/3316 [00:27<27:06,  2.01it/s]
#   1%|          | 40/3316 [00:27<27:02,  2.02it/s]
#   1%|          | 41/3316 [00:28<27:02,  2.02it/s]
#   1%|▏         | 42/3316 [00:28<27:08,  2.01it/s]
#   1%|▏         | 43/3316 [00:29<27:08,  2.01it/s]
#   1%|▏         | 44/3316 [00:29<27:12,  2.00it/s]
#   1%|▏         | 45/3316 [00:30<27:10,  2.01it/s]
#   1%|▏         | 46/3316 [00:30<27:25,  1.99it/s]
#   1%|▏         | 47/3316 [00:31<27:29,  1.98it/s]
#   1%|▏         | 48/3316 [00:31<27:40,  1.97it/s]
#   1%|▏         | 49/3316 [00:32<27:50,  1.96it/s]
#   2%|▏         | 50/3316 [00:32<27:35,  1.97it/s]
#   2%|▏         | 51/3316 [00:33<27:28,  1.98it/s]
#   2%|▏         | 52/3316 [00:33<27:21,  1.99it/s]
#   2%|▏         | 53/3316 [00:34<27:18,  1.99it/s]
#   2%|▏         | 54/3316 [00:34<27:22,  1.99it/s]
#   2%|▏         | 55/3316 [00:35<27:16,  1.99it/s]
#   2%|▏         | 56/3316 [00:35<27:22,  1.98it/s]
#   2%|▏         | 57/3316 [00:36<27:20,  1.99it/s]
#   2%|▏         | 58/3316 [00:36<27:16,  1.99it/s]
#   2%|▏         | 59/3316 [00:37<27:01,  2.01it/s]
#   2%|▏         | 60/3316 [00:37<27:04,  2.00it/s]
#   2%|▏         | 61/3316 [00:38<27:01,  2.01it/s]
#   2%|▏         | 62/3316 [00:38<26:59,  2.01it/s]
#   2%|▏         | 63/3316 [00:39<26:57,  2.01it/s]
#   2%|▏         | 64/3316 [00:39<26:58,  2.01it/s]
#   2%|▏         | 65/3316 [00:40<26:56,  2.01it/s]
#   2%|▏         | 66/3316 [00:40<26:57,  2.01it/s]
#   2%|▏         | 67/3316 [00:41<26:59,  2.01it/s]
#   2%|▏         | 68/3316 [00:41<26:59,  2.01it/s]
#   2%|▏         | 69/3316 [00:42<26:53,  2.01it/s]
#   2%|▏         | 70/3316 [00:42<26:54,  2.01it/s]
#   2%|▏         | 71/3316 [00:43<26:48,  2.02it/s]
#   2%|▏         | 72/3316 [00:43<26:47,  2.02it/s]
#   2%|▏         | 73/3316 [00:44<26:51,  2.01it/s]
#   2%|▏         | 74/3316 [00:44<26:52,  2.01it/s]
#   2%|▏         | 75/3316 [00:45<26:52,  2.01it/s]
#   2%|▏         | 76/3316 [00:45<26:48,  2.01it/s]
#   2%|▏         | 77/3316 [00:46<26:48,  2.01it/s]
#   2%|▏         | 78/3316 [00:46<27:10,  1.99it/s]
#   2%|▏         | 79/3316 [00:47<27:17,  1.98it/s]
#   2%|▏         | 80/3316 [00:47<27:31,  1.96it/s]
#   2%|▏         | 81/3316 [00:48<27:20,  1.97it/s]
#   2%|▏         | 82/3316 [00:48<27:21,  1.97it/s]
#   3%|▎         | 83/3316 [00:49<27:17,  1.97it/s]
#   3%|▎         | 84/3316 [00:49<27:02,  1.99it/s]
#   3%|▎         | 85/3316 [00:50<26:59,  2.00it/s]
#   3%|▎         | 86/3316 [00:50<27:08,  1.98it/s]
#   3%|▎         | 87/3316 [00:51<27:18,  1.97it/s]
#   3%|▎         | 88/3316 [00:51<27:26,  1.96it/s]
#   3%|▎         | 89/3316 [00:52<27:22,  1.96it/s]
#   3%|▎         | 90/3316 [00:52<27:14,  1.97it/s]
#   3%|▎         | 91/3316 [00:53<27:19,  1.97it/s]
#   3%|▎         | 92/3316 [00:53<27:12,  1.98it/s]
#   3%|▎         | 93/3316 [00:54<27:05,  1.98it/s]
#   3%|▎         | 94/3316 [00:54<27:12,  1.97it/s]
#   3%|▎         | 95/3316 [00:55<26:58,  1.99it/s]
#   3%|▎         | 96/3316 [00:55<26:56,  1.99it/s]
#   3%|▎         | 97/3316 [00:56<26:48,  2.00it/s]
#   3%|▎         | 98/3316 [00:56<26:48,  2.00it/s]
#   3%|▎         | 99/3316 [00:57<26:45,  2.00it/s]
#   3%|▎         | 100/3316 [00:57<26:45,  2.00it/s]
#   3%|▎         | 101/3316 [00:58<26:45,  2.00it/s]
#   3%|▎         | 102/3316 [00:58<26:45,  2.00it/s]
#   3%|▎         | 103/3316 [00:59<26:44,  2.00it/s]
#   3%|▎         | 104/3316 [00:59<26:44,  2.00it/s]
#   3%|▎         | 105/3316 [01:00<26:36,  2.01it/s]
#   3%|▎         | 106/3316 [01:00<26:37,  2.01it/s]
#   3%|▎         | 107/3316 [01:01<26:34,  2.01it/s]
#   3%|▎         | 108/3316 [01:01<26:40,  2.00it/s]
#   3%|▎         | 109/3316 [01:02<26:39,  2.00it/s]
#   3%|▎         | 110/3316 [01:02<26:42,  2.00it/s]
#   3%|▎         | 111/3316 [01:03<26:38,  2.00it/s]
#   3%|▎         | 112/3316 [01:03<26:38,  2.00it/s]
#   3%|▎         | 113/3316 [01:04<26:34,  2.01it/s]
#   3%|▎         | 114/3316 [01:04<26:39,  2.00it/s]
#   3%|▎         | 115/3316 [01:05<26:56,  1.98it/s]
#   3%|▎         | 116/3316 [01:05<26:58,  1.98it/s]
#   4%|▎         | 117/3316 [01:06<26:49,  1.99it/s]
#   4%|▎         | 118/3316 [01:06<26:50,  1.99it/s]
#   4%|▎         | 119/3316 [01:07<27:00,  1.97it/s]
#   4%|▎         | 120/3316 [01:07<26:54,  1.98it/s]
#   4%|▎         | 121/3316 [01:08<26:49,  1.98it/s]
#   4%|▎         | 122/3316 [01:08<26:51,  1.98it/s]
#   4%|▎         | 123/3316 [01:09<27:04,  1.97it/s]
#   4%|▎         | 124/3316 [01:09<26:53,  1.98it/s]
#   4%|▍         | 125/3316 [01:10<26:52,  1.98it/s]
#   4%|▍         | 126/3316 [01:10<26:54,  1.98it/s]
#   4%|▍         | 127/3316 [01:11<27:07,  1.96it/s]
#   4%|▍         | 128/3316 [01:11<27:01,  1.97it/s]
#   4%|▍         | 129/3316 [01:12<26:55,  1.97it/s]
#   4%|▍         | 130/3316 [01:12<26:47,  1.98it/s]
#   4%|▍         | 131/3316 [01:13<26:52,  1.97it/s]
#   4%|▍         | 132/3316 [01:13<26:43,  1.99it/s]
#   4%|▍         | 133/3316 [01:14<26:36,  1.99it/s]
#   4%|▍         | 134/3316 [01:14<26:28,  2.00it/s]
#   4%|▍         | 135/3316 [01:15<26:24,  2.01it/s]
#   4%|▍         | 136/3316 [01:15<26:19,  2.01it/s]
#   4%|▍         | 137/3316 [01:16<26:21,  2.01it/s]
#   4%|▍         | 138/3316 [01:16<26:18,  2.01it/s]
#   4%|▍         | 139/3316 [01:17<26:20,  2.01it/s]
#   4%|▍         | 140/3316 [01:17<26:23,  2.01it/s]
#   4%|▍         | 141/3316 [01:18<26:26,  2.00it/s]
#   4%|▍         | 142/3316 [01:18<26:31,  1.99it/s]
#   4%|▍         | 143/3316 [01:19<26:28,  2.00it/s]
#   4%|▍         | 144/3316 [01:19<26:18,  2.01it/s]
#   4%|▍         | 145/3316 [01:20<26:16,  2.01it/s]
#   4%|▍         | 146/3316 [01:20<26:17,  2.01it/s]
#   4%|▍         | 147/3316 [01:21<26:15,  2.01it/s]
#   4%|▍         | 148/3316 [01:21<26:17,  2.01it/s]
#   4%|▍         | 149/3316 [01:22<26:14,  2.01it/s]
#   5%|▍         | 150/3316 [01:22<26:22,  2.00it/s]
#   5%|▍         | 151/3316 [01:23<26:21,  2.00it/s]
#   5%|▍         | 152/3316 [01:23<26:20,  2.00it/s]
#   5%|▍         | 153/3316 [01:24<26:23,  2.00it/s]
#   5%|▍         | 154/3316 [01:24<26:26,  1.99it/s]
#   5%|▍         | 155/3316 [01:25<26:25,  1.99it/s]
#   5%|▍         | 156/3316 [01:25<26:36,  1.98it/s]
#   5%|▍         | 157/3316 [01:26<26:47,  1.96it/s]
#   5%|▍         | 158/3316 [01:26<26:43,  1.97it/s]
#   5%|▍         | 159/3316 [01:27<26:40,  1.97it/s]
#   5%|▍         | 160/3316 [01:27<26:34,  1.98it/s]
#   5%|▍         | 161/3316 [01:28<26:33,  1.98it/s]
#   5%|▍         | 162/3316 [01:28<26:28,  1.99it/s]
#   5%|▍         | 163/3316 [01:29<26:27,  1.99it/s]
#   5%|▍         | 164/3316 [01:29<26:25,  1.99it/s]
#   5%|▍         | 165/3316 [01:30<26:22,  1.99it/s]
#   5%|▌         | 166/3316 [01:30<26:31,  1.98it/s]
#   5%|▌         | 167/3316 [01:31<26:28,  1.98it/s]
#   5%|▌         | 168/3316 [01:31<26:22,  1.99it/s]
#   5%|▌         | 169/3316 [01:32<26:16,  2.00it/s]
#   5%|▌         | 170/3316 [01:32<26:14,  2.00it/s]
#   5%|▌         | 171/3316 [01:33<26:12,  2.00it/s]
#   5%|▌         | 172/3316 [01:33<26:09,  2.00it/s]
#   5%|▌         | 173/3316 [01:34<26:06,  2.01it/s]
#   5%|▌         | 174/3316 [01:34<26:06,  2.01it/s]
#   5%|▌         | 175/3316 [01:35<26:06,  2.01it/s]
#   5%|▌         | 176/3316 [01:35<26:04,  2.01it/s]
#   5%|▌         | 177/3316 [01:36<26:01,  2.01it/s]
#   5%|▌         | 178/3316 [01:36<26:01,  2.01it/s]
#   5%|▌         | 179/3316 [01:37<25:56,  2.01it/s]
#   5%|▌         | 180/3316 [01:37<25:54,  2.02it/s]
#   5%|▌         | 181/3316 [01:38<25:56,  2.01it/s]
#   5%|▌         | 182/3316 [01:38<26:00,  2.01it/s]
#   6%|▌         | 183/3316 [01:39<25:59,  2.01it/s]
#   6%|▌         | 184/3316 [01:39<26:04,  2.00it/s]
#   6%|▌         | 185/3316 [01:40<26:04,  2.00it/s]
#   6%|▌         | 186/3316 [01:40<26:06,  2.00it/s]
#   6%|▌         | 187/3316 [01:41<26:09,  1.99it/s]
#   6%|▌         | 188/3316 [01:41<26:04,  2.00it/s]
#   6%|▌         | 189/3316 [01:42<26:11,  1.99it/s]
#   6%|▌         | 190/3316 [01:42<26:11,  1.99it/s]
#   6%|▌         | 191/3316 [01:43<26:10,  1.99it/s]
#   6%|▌         | 192/3316 [01:43<26:09,  1.99it/s]
#   6%|▌         | 193/3316 [01:44<26:09,  1.99it/s]
#   6%|▌         | 194/3316 [01:44<26:08,  1.99it/s]
#   6%|▌         | 195/3316 [01:45<26:10,  1.99it/s]
#   6%|▌         | 196/3316 [01:45<26:25,  1.97it/s]
#   6%|▌         | 197/3316 [01:46<26:16,  1.98it/s]
#   6%|▌         | 198/3316 [01:46<26:26,  1.97it/s]
#   6%|▌         | 199/3316 [01:47<26:30,  1.96it/s]
#   6%|▌         | 200/3316 [01:47<26:18,  1.97it/s]
#   6%|▌         | 201/3316 [01:48<26:22,  1.97it/s]
#   6%|▌         | 202/3316 [01:48<26:20,  1.97it/s]
#   6%|▌         | 203/3316 [01:49<26:29,  1.96it/s]
#   6%|▌         | 204/3316 [01:49<26:13,  1.98it/s]
#   6%|▌         | 205/3316 [01:50<26:07,  1.98it/s]
#   6%|▌         | 206/3316 [01:50<26:06,  1.98it/s]
#   6%|▌         | 207/3316 [01:51<26:01,  1.99it/s]
#   6%|▋         | 208/3316 [01:51<25:55,  2.00it/s]
#   6%|▋         | 209/3316 [01:52<25:46,  2.01it/s]
#   6%|▋         | 210/3316 [01:52<25:42,  2.01it/s]
#   6%|▋         | 211/3316 [01:53<25:45,  2.01it/s]
#   6%|▋         | 212/3316 [01:53<25:49,  2.00it/s]
#   6%|▋         | 213/3316 [01:54<25:55,  2.00it/s]
#   6%|▋         | 214/3316 [01:54<25:54,  2.00it/s]
#   6%|▋         | 215/3316 [01:55<25:54,  2.00it/s]
#   7%|▋         | 216/3316 [01:55<25:55,  1.99it/s]
#   7%|▋         | 217/3316 [01:56<25:56,  1.99it/s]
#   7%|▋         | 218/3316 [01:56<25:50,  2.00it/s]
#   7%|▋         | 219/3316 [01:57<25:49,  2.00it/s]
#   7%|▋         | 220/3316 [01:57<25:53,  1.99it/s]
#   7%|▋         | 221/3316 [01:58<25:50,  2.00it/s]
#   7%|▋         | 222/3316 [01:58<25:46,  2.00it/s]
#   7%|▋         | 223/3316 [01:59<25:44,  2.00it/s]
#   7%|▋         | 224/3316 [01:59<25:46,  2.00it/s]
#   7%|▋         | 225/3316 [02:00<25:49,  2.00it/s]
#   7%|▋         | 226/3316 [02:00<25:49,  1.99it/s]
#   7%|▋         | 227/3316 [02:01<25:52,  1.99it/s]
#   7%|▋         | 228/3316 [02:01<26:02,  1.98it/s]
#   7%|▋         | 229/3316 [02:02<26:16,  1.96it/s]
#   7%|▋         | 230/3316 [02:02<26:09,  1.97it/s]
#   7%|▋         | 231/3316 [02:03<26:08,  1.97it/s]
#   7%|▋         | 232/3316 [02:03<26:04,  1.97it/s]
#   7%|▋         | 233/3316 [02:04<26:09,  1.96it/s]
#   7%|▋         | 234/3316 [02:04<26:03,  1.97it/s]
#   7%|▋         | 235/3316 [02:05<25:59,  1.98it/s]
#   7%|▋         | 236/3316 [02:05<25:56,  1.98it/s]
#   7%|▋         | 237/3316 [02:06<25:50,  1.99it/s]
#   7%|▋         | 238/3316 [02:06<25:49,  1.99it/s]
#   7%|▋         | 239/3316 [02:07<25:45,  1.99it/s]
#   7%|▋         | 240/3316 [02:07<25:44,  1.99it/s]
#   7%|▋         | 241/3316 [02:08<25:59,  1.97it/s]
#   7%|▋         | 242/3316 [02:09<25:50,  1.98it/s]
#   7%|▋         | 243/3316 [02:09<25:48,  1.98it/s]
#   7%|▋         | 244/3316 [02:10<25:39,  2.00it/s]
#   7%|▋         | 245/3316 [02:10<25:37,  2.00it/s]
#   7%|▋         | 246/3316 [02:11<25:36,  2.00it/s]
#   7%|▋         | 247/3316 [02:11<25:37,  2.00it/s]
#   7%|▋         | 248/3316 [02:12<25:35,  2.00it/s]
#   8%|▊         | 249/3316 [02:12<25:37,  2.00it/s]
#   8%|▊         | 250/3316 [02:13<25:38,  1.99it/s]
#   8%|▊         | 251/3316 [02:13<25:39,  1.99it/s]
#   8%|▊         | 252/3316 [02:14<25:38,  1.99it/s]
#   8%|▊         | 253/3316 [02:14<25:37,  1.99it/s]
#   8%|▊         | 254/3316 [02:15<25:34,  2.00it/s]
#   8%|▊         | 255/3316 [02:15<25:38,  1.99it/s]
#   8%|▊         | 256/3316 [02:16<25:32,  2.00it/s]
#   8%|▊         | 257/3316 [02:16<25:32,  2.00it/s]
#   8%|▊         | 258/3316 [02:17<25:31,  2.00it/s]
#   8%|▊         | 259/3316 [02:17<25:34,  1.99it/s]
#   8%|▊         | 260/3316 [02:18<25:32,  1.99it/s]
#   8%|▊         | 261/3316 [02:18<25:34,  1.99it/s]
#   8%|▊         | 262/3316 [02:19<25:37,  1.99it/s]
#   8%|▊         | 263/3316 [02:19<25:32,  1.99it/s]
#   8%|▊         | 264/3316 [02:20<25:36,  1.99it/s]
#   8%|▊         | 265/3316 [02:20<25:42,  1.98it/s]
#   8%|▊         | 266/3316 [02:21<25:45,  1.97it/s]
#   8%|▊         | 267/3316 [02:21<25:47,  1.97it/s]
#   8%|▊         | 268/3316 [02:22<25:51,  1.96it/s]
#   8%|▊         | 269/3316 [02:22<25:53,  1.96it/s]
#   8%|▊         | 270/3316 [02:23<25:40,  1.98it/s]
#   8%|▊         | 271/3316 [02:23<25:34,  1.98it/s]
#   8%|▊         | 272/3316 [02:24<25:42,  1.97it/s]
#   8%|▊         | 273/3316 [02:24<25:52,  1.96it/s]
#   8%|▊         | 274/3316 [02:25<25:59,  1.95it/s]
#   8%|▊         | 275/3316 [02:25<25:50,  1.96it/s]
#   8%|▊         | 276/3316 [02:26<25:40,  1.97it/s]
#   8%|▊         | 277/3316 [02:26<25:35,  1.98it/s]
#   8%|▊         | 278/3316 [02:27<25:30,  1.99it/s]
#   8%|▊         | 279/3316 [02:27<25:22,  1.99it/s]
#   8%|▊         | 280/3316 [02:28<25:17,  2.00it/s]
#   8%|▊         | 281/3316 [02:28<25:18,  2.00it/s]
#   9%|▊         | 282/3316 [02:29<25:16,  2.00it/s]
#   9%|▊         | 283/3316 [02:29<25:20,  2.00it/s]
#   9%|▊         | 284/3316 [02:30<25:19,  2.00it/s]
#   9%|▊         | 285/3316 [02:30<25:15,  2.00it/s]
#   9%|▊         | 286/3316 [02:31<25:14,  2.00it/s]
#   9%|▊         | 287/3316 [02:31<25:15,  2.00it/s]
#   9%|▊         | 288/3316 [02:32<25:23,  1.99it/s]
#   9%|▊         | 289/3316 [02:32<25:22,  1.99it/s]
#   9%|▊         | 290/3316 [02:33<25:17,  1.99it/s]
#   9%|▉         | 291/3316 [02:33<25:17,  1.99it/s]
#   9%|▉         | 292/3316 [02:34<25:16,  1.99it/s]
#   9%|▉         | 293/3316 [02:34<25:11,  2.00it/s]
#   9%|▉         | 294/3316 [02:35<25:07,  2.01it/s]
#   9%|▉         | 295/3316 [02:35<25:14,  1.99it/s]
#   9%|▉         | 296/3316 [02:36<25:17,  1.99it/s]
#   9%|▉         | 297/3316 [02:36<25:16,  1.99it/s]
#   9%|▉         | 298/3316 [02:37<25:19,  1.99it/s]
#   9%|▉         | 299/3316 [02:37<25:32,  1.97it/s]
#   9%|▉         | 300/3316 [02:38<25:44,  1.95it/s]
#   9%|▉         | 301/3316 [02:38<25:35,  1.96it/s]
#   9%|▉         | 302/3316 [02:39<25:25,  1.98it/s]
#   9%|▉         | 303/3316 [02:39<25:29,  1.97it/s]
#   9%|▉         | 304/3316 [02:40<25:39,  1.96it/s]
#   9%|▉         | 305/3316 [02:40<25:31,  1.97it/s]
#   9%|▉         | 306/3316 [02:41<25:27,  1.97it/s]
#   9%|▉         | 307/3316 [02:41<25:34,  1.96it/s]
#   9%|▉         | 308/3316 [02:42<25:34,  1.96it/s]
#   9%|▉         | 309/3316 [02:42<25:27,  1.97it/s]
#   9%|▉         | 310/3316 [02:43<25:25,  1.97it/s]
#   9%|▉         | 311/3316 [02:43<25:39,  1.95it/s]
#   9%|▉         | 312/3316 [02:44<25:25,  1.97it/s]
#   9%|▉         | 313/3316 [02:44<25:28,  1.96it/s]
#   9%|▉         | 314/3316 [02:45<25:27,  1.97it/s]
#   9%|▉         | 315/3316 [02:45<25:17,  1.98it/s]
#  10%|▉         | 316/3316 [02:46<25:06,  1.99it/s]
#  10%|▉         | 317/3316 [02:46<25:01,  2.00it/s]
#  10%|▉         | 318/3316 [02:47<24:55,  2.01it/s]
#  10%|▉         | 319/3316 [02:47<24:54,  2.01it/s]
#  10%|▉         | 320/3316 [02:48<24:55,  2.00it/s]
#  10%|▉         | 321/3316 [02:48<24:51,  2.01it/s]
#  10%|▉         | 322/3316 [02:49<24:52,  2.01it/s]
#  10%|▉         | 323/3316 [02:49<24:49,  2.01it/s]
#  10%|▉         | 324/3316 [02:50<24:44,  2.02it/s]
#  10%|▉         | 325/3316 [02:50<24:48,  2.01it/s]
#  10%|▉         | 326/3316 [02:51<24:51,  2.00it/s]
#  10%|▉         | 327/3316 [02:51<24:46,  2.01it/s]
#  10%|▉         | 328/3316 [02:52<24:49,  2.01it/s]
#  10%|▉         | 329/3316 [02:52<24:49,  2.01it/s]
#  10%|▉         | 330/3316 [02:53<24:46,  2.01it/s]
#  10%|▉         | 331/3316 [02:53<24:44,  2.01it/s]
#  10%|█         | 332/3316 [02:54<24:48,  2.00it/s]
#  10%|█         | 333/3316 [02:54<24:44,  2.01it/s]
#  10%|█         | 334/3316 [02:55<24:40,  2.01it/s]
#  10%|█         | 335/3316 [02:55<25:01,  1.99it/s]
#  10%|█         | 336/3316 [02:56<25:07,  1.98it/s]
#  10%|█         | 337/3316 [02:56<25:21,  1.96it/s]
#  10%|█         | 338/3316 [02:57<25:36,  1.94it/s]
#  10%|█         | 339/3316 [02:57<25:24,  1.95it/s]
#  10%|█         | 340/3316 [02:58<25:21,  1.96it/s]
#  10%|█         | 341/3316 [02:58<25:16,  1.96it/s]
#  10%|█         | 342/3316 [02:59<25:10,  1.97it/s]
#  10%|█         | 343/3316 [02:59<25:08,  1.97it/s]
#  10%|█         | 344/3316 [03:00<25:01,  1.98it/s]
#  10%|█         | 345/3316 [03:00<24:51,  1.99it/s]
#  10%|█         | 346/3316 [03:01<24:51,  1.99it/s]
#  10%|█         | 347/3316 [03:01<25:02,  1.98it/s]
#  10%|█         | 348/3316 [03:02<25:07,  1.97it/s]
#  11%|█         | 349/3316 [03:02<25:09,  1.97it/s]
#  11%|█         | 350/3316 [03:03<25:05,  1.97it/s]
#  11%|█         | 351/3316 [03:03<24:51,  1.99it/s]
#  11%|█         | 352/3316 [03:04<24:48,  1.99it/s]
#  11%|█         | 353/3316 [03:04<24:50,  1.99it/s]
#  11%|█         | 354/3316 [03:05<24:47,  1.99it/s]
#  11%|█         | 355/3316 [03:05<24:45,  1.99it/s]
#  11%|█         | 356/3316 [03:06<24:40,  2.00it/s]
#  11%|█         | 357/3316 [03:06<24:33,  2.01it/s]
#  11%|█         | 358/3316 [03:07<24:34,  2.01it/s]
#  11%|█         | 359/3316 [03:07<24:40,  2.00it/s]
#  11%|█         | 360/3316 [03:08<24:37,  2.00it/s]
#  11%|█         | 361/3316 [03:08<24:36,  2.00it/s]
#  11%|█         | 362/3316 [03:09<24:36,  2.00it/s]
#  11%|█         | 363/3316 [03:09<24:37,  2.00it/s]
#  11%|█         | 364/3316 [03:10<24:32,  2.00it/s]
#  11%|█         | 365/3316 [03:10<24:38,  2.00it/s]
#  11%|█         | 366/3316 [03:11<24:35,  2.00it/s]
#  11%|█         | 367/3316 [03:11<24:36,  2.00it/s]
#  11%|█         | 368/3316 [03:12<24:37,  2.00it/s]
#  11%|█         | 369/3316 [03:12<24:35,  2.00it/s]
#  11%|█         | 370/3316 [03:13<24:29,  2.00it/s]
#  11%|█         | 371/3316 [03:13<24:27,  2.01it/s]
#  11%|█         | 372/3316 [03:14<24:28,  2.01it/s]
#  11%|█         | 373/3316 [03:14<24:28,  2.00it/s]
#  11%|█▏        | 374/3316 [03:15<24:37,  1.99it/s]
#  11%|█▏        | 375/3316 [03:15<24:50,  1.97it/s]
#  11%|█▏        | 376/3316 [03:16<24:47,  1.98it/s]
#  11%|█▏        | 377/3316 [03:16<24:43,  1.98it/s]
#  11%|█▏        | 378/3316 [03:17<24:58,  1.96it/s]
#  11%|█▏        | 379/3316 [03:17<24:45,  1.98it/s]
#  11%|█▏        | 380/3316 [03:18<24:59,  1.96it/s]
#  11%|█▏        | 381/3316 [03:18<24:57,  1.96it/s]
#  12%|█▏        | 382/3316 [03:19<24:56,  1.96it/s]
#  12%|█▏        | 383/3316 [03:20<24:52,  1.97it/s]
#  12%|█▏        | 384/3316 [03:20<24:56,  1.96it/s]
#  12%|█▏        | 385/3316 [03:21<24:46,  1.97it/s]
#  12%|█▏        | 386/3316 [03:21<24:35,  1.99it/s]
#  12%|█▏        | 387/3316 [03:22<24:43,  1.97it/s]
#  12%|█▏        | 388/3316 [03:22<24:38,  1.98it/s]
#  12%|█▏        | 389/3316 [03:23<24:33,  1.99it/s]
#  12%|█▏        | 390/3316 [03:23<24:28,  1.99it/s]
#  12%|█▏        | 391/3316 [03:24<24:31,  1.99it/s]
#  12%|█▏        | 392/3316 [03:24<24:29,  1.99it/s]
#  12%|█▏        | 393/3316 [03:25<24:29,  1.99it/s]
#  12%|█▏        | 394/3316 [03:25<24:26,  1.99it/s]
#  12%|█▏        | 395/3316 [03:26<24:25,  1.99it/s]
#  12%|█▏        | 396/3316 [03:26<24:17,  2.00it/s]
#  12%|█▏        | 397/3316 [03:27<24:17,  2.00it/s]
#  12%|█▏        | 398/3316 [03:27<24:17,  2.00it/s]
#  12%|█▏        | 399/3316 [03:28<24:21,  2.00it/s]
#  12%|█▏        | 400/3316 [03:28<24:19,  2.00it/s]
#  12%|█▏        | 401/3316 [03:29<24:18,  2.00it/s]
#  12%|█▏        | 402/3316 [03:29<24:18,  2.00it/s]
#  12%|█▏        | 403/3316 [03:30<24:21,  1.99it/s]
#  12%|█▏        | 404/3316 [03:30<24:22,  1.99it/s]
#  12%|█▏        | 405/3316 [03:31<24:16,  2.00it/s]
#  12%|█▏        | 406/3316 [03:31<24:17,  2.00it/s]
#  12%|█▏        | 407/3316 [03:32<24:23,  1.99it/s]
#  12%|█▏        | 408/3316 [03:32<24:17,  2.00it/s]
#  12%|█▏        | 409/3316 [03:33<24:20,  1.99it/s]
#  12%|█▏        | 410/3316 [03:33<24:41,  1.96it/s]
#  12%|█▏        | 411/3316 [03:34<24:32,  1.97it/s]
#  12%|█▏        | 412/3316 [03:34<24:26,  1.98it/s]
#  12%|█▏        | 413/3316 [03:35<24:25,  1.98it/s]
#  12%|█▏        | 414/3316 [03:35<24:23,  1.98it/s]
#  13%|█▎        | 415/3316 [03:36<24:25,  1.98it/s]
#  13%|█▎        | 416/3316 [03:36<24:26,  1.98it/s]
#  13%|█▎        | 417/3316 [03:37<24:27,  1.98it/s]
#  13%|█▎        | 418/3316 [03:37<24:33,  1.97it/s]
#  13%|█▎        | 419/3316 [03:38<24:31,  1.97it/s]
#  13%|█▎        | 420/3316 [03:38<24:26,  1.98it/s]
#  13%|█▎        | 421/3316 [03:39<24:46,  1.95it/s]
#  13%|█▎        | 422/3316 [03:39<24:35,  1.96it/s]
#  13%|█▎        | 423/3316 [03:40<24:27,  1.97it/s]
#  13%|█▎        | 424/3316 [03:40<24:21,  1.98it/s]
#  13%|█▎        | 425/3316 [03:41<24:16,  1.99it/s]
#  13%|█▎        | 426/3316 [03:41<24:15,  1.99it/s]
#  13%|█▎        | 427/3316 [03:42<24:06,  2.00it/s]
#  13%|█▎        | 428/3316 [03:42<24:02,  2.00it/s]
#  13%|█▎        | 429/3316 [03:43<23:58,  2.01it/s]
#  13%|█▎        | 430/3316 [03:43<23:59,  2.00it/s]
#  13%|█▎        | 431/3316 [03:44<24:04,  2.00it/s]
#  13%|█▎        | 432/3316 [03:44<24:06,  1.99it/s]
#  13%|█▎        | 433/3316 [03:45<24:05,  2.00it/s]
#  13%|█▎        | 434/3316 [03:45<24:03,  2.00it/s]
#  13%|█▎        | 435/3316 [03:46<24:00,  2.00it/s]
#  13%|█▎        | 436/3316 [03:46<24:00,  2.00it/s]
#  13%|█▎        | 437/3316 [03:47<24:00,  2.00it/s]
#  13%|█▎        | 438/3316 [03:47<24:04,  1.99it/s]
#  13%|█▎        | 439/3316 [03:48<24:05,  1.99it/s]
#  13%|█▎        | 440/3316 [03:48<24:00,  2.00it/s]
#  13%|█▎        | 441/3316 [03:49<24:00,  2.00it/s]
#  13%|█▎        | 442/3316 [03:49<24:00,  2.00it/s]
#  13%|█▎        | 443/3316 [03:50<23:58,  2.00it/s]
#  13%|█▎        | 444/3316 [03:50<24:01,  1.99it/s]
#  13%|█▎        | 445/3316 [03:51<24:16,  1.97it/s]
#  13%|█▎        | 446/3316 [03:51<24:10,  1.98it/s]
#  13%|█▎        | 447/3316 [03:52<24:26,  1.96it/s]
#  14%|█▎        | 448/3316 [03:52<24:20,  1.96it/s]
#  14%|█▎        | 449/3316 [03:53<24:31,  1.95it/s]
#  14%|█▎        | 450/3316 [03:53<24:30,  1.95it/s]
#  14%|█▎        | 451/3316 [03:54<24:31,  1.95it/s]
#  14%|█▎        | 452/3316 [03:54<24:22,  1.96it/s]
#  14%|█▎        | 453/3316 [03:55<24:35,  1.94it/s]
#  14%|█▎        | 454/3316 [03:55<24:38,  1.94it/s]
#  14%|█▎        | 455/3316 [03:56<24:21,  1.96it/s]
#  14%|█▍        | 456/3316 [03:56<24:24,  1.95it/s]
#  14%|█▍        | 457/3316 [03:57<24:30,  1.94it/s]
#  14%|█▍        | 458/3316 [03:57<24:19,  1.96it/s]
#  14%|█▍        | 459/3316 [03:58<24:10,  1.97it/s]
#  14%|█▍        | 460/3316 [03:58<24:05,  1.98it/s]
#  14%|█▍        | 461/3316 [03:59<24:03,  1.98it/s]
#  14%|█▍        | 462/3316 [03:59<24:00,  1.98it/s]
#  14%|█▍        | 463/3316 [04:00<23:58,  1.98it/s]
#  14%|█▍        | 464/3316 [04:00<24:00,  1.98it/s]
#  14%|█▍        | 465/3316 [04:01<23:58,  1.98it/s]
#  14%|█▍        | 466/3316 [04:01<23:59,  1.98it/s]
#  14%|█▍        | 467/3316 [04:02<23:58,  1.98it/s]
#  14%|█▍        | 468/3316 [04:02<23:54,  1.98it/s]
#  14%|█▍        | 469/3316 [04:03<23:56,  1.98it/s]
#  14%|█▍        | 470/3316 [04:03<23:56,  1.98it/s]
#  14%|█▍        | 471/3316 [04:04<23:59,  1.98it/s]
#  14%|█▍        | 472/3316 [04:04<23:56,  1.98it/s]
#  14%|█▍        | 473/3316 [04:05<23:54,  1.98it/s]
#  14%|█▍        | 474/3316 [04:05<24:00,  1.97it/s]
#  14%|█▍        | 475/3316 [04:06<23:52,  1.98it/s]
#  14%|█▍        | 476/3316 [04:06<23:49,  1.99it/s]
#  14%|█▍        | 477/3316 [04:07<23:46,  1.99it/s]
#  14%|█▍        | 478/3316 [04:07<23:40,  2.00it/s]
#  14%|█▍        | 479/3316 [04:08<23:36,  2.00it/s]
#  14%|█▍        | 480/3316 [04:08<23:39,  2.00it/s]
#  15%|█▍        | 481/3316 [04:09<23:43,  1.99it/s]
#  15%|█▍        | 482/3316 [04:09<24:00,  1.97it/s]
#  15%|█▍        | 483/3316 [04:10<23:54,  1.97it/s]
#  15%|█▍        | 484/3316 [04:10<23:57,  1.97it/s]
#  15%|█▍        | 485/3316 [04:11<23:46,  1.98it/s]
#  15%|█▍        | 486/3316 [04:11<23:48,  1.98it/s]
#  15%|█▍        | 487/3316 [04:12<23:44,  1.99it/s]
#  15%|█▍        | 488/3316 [04:12<23:49,  1.98it/s]
#  15%|█▍        | 489/3316 [04:13<23:52,  1.97it/s]
#  15%|█▍        | 490/3316 [04:14<23:46,  1.98it/s]
#  15%|█▍        | 491/3316 [04:14<23:57,  1.96it/s]
#  15%|█▍        | 492/3316 [04:15<24:07,  1.95it/s]
#  15%|█▍        | 493/3316 [04:15<24:18,  1.94it/s]
#  15%|█▍        | 494/3316 [04:16<24:02,  1.96it/s]
#  15%|█▍        | 495/3316 [04:16<24:11,  1.94it/s]
#  15%|█▍        | 496/3316 [04:17<24:04,  1.95it/s]
#  15%|█▍        | 497/3316 [04:17<24:02,  1.95it/s]
#  15%|█▌        | 498/3316 [04:18<24:03,  1.95it/s]
#  15%|█▌        | 499/3316 [04:18<23:51,  1.97it/s]
#  15%|█▌        | 500/3316 [04:19<23:44,  1.98it/s]
#  15%|█▌        | 501/3316 [04:19<23:40,  1.98it/s]
#  15%|█▌        | 502/3316 [04:20<23:38,  1.98it/s]
#  15%|█▌        | 503/3316 [04:20<23:37,  1.98it/s]
#  15%|█▌        | 504/3316 [04:21<23:33,  1.99it/s]
#  15%|█▌        | 505/3316 [04:21<23:41,  1.98it/s]
#  15%|█▌        | 506/3316 [04:22<23:37,  1.98it/s]
#  15%|█▌        | 507/3316 [04:22<23:25,  2.00it/s]
#  15%|█▌        | 508/3316 [04:23<23:27,  2.00it/s]
#  15%|█▌        | 509/3316 [04:23<23:21,  2.00it/s]
#  15%|█▌        | 510/3316 [04:24<23:23,  2.00it/s]
#  15%|█▌        | 511/3316 [04:24<23:20,  2.00it/s]
#  15%|█▌        | 512/3316 [04:25<23:20,  2.00it/s]
#  15%|█▌        | 513/3316 [04:25<23:15,  2.01it/s]
#  16%|█▌        | 514/3316 [04:26<23:21,  2.00it/s]
#  16%|█▌        | 515/3316 [04:26<23:23,  2.00it/s]
#  16%|█▌        | 516/3316 [04:27<23:23,  2.00it/s]
#  16%|█▌        | 517/3316 [04:27<23:24,  1.99it/s]
#  16%|█▌        | 518/3316 [04:28<23:16,  2.00it/s]
#  16%|█▌        | 519/3316 [04:28<23:19,  2.00it/s]
#  16%|█▌        | 520/3316 [04:29<23:32,  1.98it/s]
#  16%|█▌        | 521/3316 [04:29<23:27,  1.99it/s]
#  16%|█▌        | 522/3316 [04:30<23:30,  1.98it/s]
#  16%|█▌        | 523/3316 [04:30<23:32,  1.98it/s]
#  16%|█▌        | 524/3316 [04:31<23:25,  1.99it/s]
#  16%|█▌        | 525/3316 [04:31<23:34,  1.97it/s]
#  16%|█▌        | 526/3316 [04:32<23:34,  1.97it/s]
#  16%|█▌        | 527/3316 [04:32<23:42,  1.96it/s]
#  16%|█▌        | 528/3316 [04:33<23:43,  1.96it/s]
#  16%|█▌        | 529/3316 [04:33<23:43,  1.96it/s]
#  16%|█▌        | 530/3316 [04:34<23:39,  1.96it/s]
#  16%|█▌        | 531/3316 [04:34<23:35,  1.97it/s]
#  16%|█▌        | 532/3316 [04:35<23:49,  1.95it/s]
#  16%|█▌        | 533/3316 [04:35<23:40,  1.96it/s]
#  16%|█▌        | 534/3316 [04:36<23:43,  1.95it/s]
#  16%|█▌        | 535/3316 [04:36<23:36,  1.96it/s]
#  16%|█▌        | 536/3316 [04:37<23:34,  1.97it/s]
#  16%|█▌        | 537/3316 [04:37<23:25,  1.98it/s]
#  16%|█▌        | 538/3316 [04:38<23:19,  1.98it/s]
#  16%|█▋        | 539/3316 [04:38<23:10,  2.00it/s]
#  16%|█▋        | 540/3316 [04:39<23:15,  1.99it/s]
#  16%|█▋        | 541/3316 [04:39<23:17,  1.99it/s]
#  16%|█▋        | 542/3316 [04:40<23:14,  1.99it/s]
#  16%|█▋        | 543/3316 [04:40<23:04,  2.00it/s]
#  16%|█▋        | 544/3316 [04:41<23:01,  2.01it/s]
#  16%|█▋        | 545/3316 [04:41<23:03,  2.00it/s]
#  16%|█▋        | 546/3316 [04:42<23:05,  2.00it/s]
#  16%|█▋        | 547/3316 [04:42<23:14,  1.99it/s]
#  17%|█▋        | 548/3316 [04:43<23:09,  1.99it/s]
#  17%|█▋        | 549/3316 [04:43<23:12,  1.99it/s]
#  17%|█▋        | 550/3316 [04:44<23:02,  2.00it/s]
#  17%|█▋        | 551/3316 [04:44<23:02,  2.00it/s]
#  17%|█▋        | 552/3316 [04:45<22:58,  2.01it/s]
#  17%|█▋        | 553/3316 [04:45<22:57,  2.01it/s]
#  17%|█▋        | 554/3316 [04:46<23:01,  2.00it/s]
#  17%|█▋        | 555/3316 [04:46<23:10,  1.99it/s]
#  17%|█▋        | 556/3316 [04:47<23:13,  1.98it/s]
#  17%|█▋        | 557/3316 [04:47<23:13,  1.98it/s]
#  17%|█▋        | 558/3316 [04:48<23:08,  1.99it/s]
#  17%|█▋        | 559/3316 [04:48<23:15,  1.98it/s]
#  17%|█▋        | 560/3316 [04:49<23:11,  1.98it/s]
#  17%|█▋        | 561/3316 [04:49<23:10,  1.98it/s]
#  17%|█▋        | 562/3316 [04:50<23:06,  1.99it/s]
#  17%|█▋        | 563/3316 [04:50<23:06,  1.99it/s]
#  17%|█▋        | 564/3316 [04:51<23:10,  1.98it/s]
#  17%|█▋        | 565/3316 [04:51<23:01,  1.99it/s]
#  17%|█▋        | 566/3316 [04:52<23:08,  1.98it/s]
#  17%|█▋        | 567/3316 [04:52<23:04,  1.99it/s]
#  17%|█▋        | 568/3316 [04:53<23:10,  1.98it/s]
#  17%|█▋        | 569/3316 [04:53<23:11,  1.97it/s]
#  17%|█▋        | 570/3316 [04:54<23:26,  1.95it/s]
#  17%|█▋        | 571/3316 [04:54<23:23,  1.96it/s]
#  17%|█▋        | 572/3316 [04:55<23:15,  1.97it/s]
#  17%|█▋        | 573/3316 [04:55<23:08,  1.97it/s]
#  17%|█▋        | 574/3316 [04:56<23:02,  1.98it/s]
#  17%|█▋        | 575/3316 [04:56<23:00,  1.99it/s]
#  17%|█▋        | 576/3316 [04:57<22:58,  1.99it/s]
#  17%|█▋        | 577/3316 [04:57<22:57,  1.99it/s]
#  17%|█▋        | 578/3316 [04:58<22:52,  1.99it/s]
#  17%|█▋        | 579/3316 [04:58<22:44,  2.01it/s]
#  17%|█▋        | 580/3316 [04:59<22:48,  2.00it/s]
#  18%|█▊        | 581/3316 [04:59<22:51,  1.99it/s]
#  18%|█▊        | 582/3316 [05:00<22:52,  1.99it/s]
#  18%|█▊        | 583/3316 [05:00<22:51,  1.99it/s]
#  18%|█▊        | 584/3316 [05:01<22:51,  1.99it/s]
#  18%|█▊        | 585/3316 [05:01<22:49,  1.99it/s]
#  18%|█▊        | 586/3316 [05:02<22:47,  2.00it/s]
#  18%|█▊        | 587/3316 [05:02<22:46,  2.00it/s]
#  18%|█▊        | 588/3316 [05:03<22:43,  2.00it/s]
#  18%|█▊        | 589/3316 [05:03<22:45,  2.00it/s]
#  18%|█▊        | 590/3316 [05:04<22:52,  1.99it/s]
#  18%|█▊        | 591/3316 [05:04<22:58,  1.98it/s]
#  18%|█▊        | 592/3316 [05:05<22:55,  1.98it/s]
#  18%|█▊        | 593/3316 [05:05<22:52,  1.98it/s]
#  18%|█▊        | 594/3316 [05:06<22:50,  1.99it/s]
#  18%|█▊        | 595/3316 [05:06<22:47,  1.99it/s]
#  18%|█▊        | 596/3316 [05:07<22:50,  1.99it/s]
#  18%|█▊        | 597/3316 [05:07<22:45,  1.99it/s]
#  18%|█▊        | 598/3316 [05:08<22:49,  1.99it/s]
#  18%|█▊        | 599/3316 [05:08<22:51,  1.98it/s]
#  18%|█▊        | 600/3316 [05:09<22:56,  1.97it/s]
#  18%|█▊        | 601/3316 [05:10<23:05,  1.96it/s]
#  18%|█▊        | 602/3316 [05:10<22:54,  1.97it/s]
#  18%|█▊        | 603/3316 [05:11<23:04,  1.96it/s]
#  18%|█▊        | 604/3316 [05:11<23:08,  1.95it/s]
#  18%|█▊        | 605/3316 [05:12<23:22,  1.93it/s]
#  18%|█▊        | 606/3316 [05:12<23:24,  1.93it/s]
#  18%|█▊        | 607/3316 [05:13<23:12,  1.95it/s]
#  18%|█▊        | 608/3316 [05:13<23:21,  1.93it/s]
#  18%|█▊        | 609/3316 [05:14<23:09,  1.95it/s]
#  18%|█▊        | 610/3316 [05:14<23:00,  1.96it/s]
#  18%|█▊        | 611/3316 [05:15<22:56,  1.96it/s]
#  18%|█▊        | 612/3316 [05:15<22:51,  1.97it/s]
#  18%|█▊        | 613/3316 [05:16<22:48,  1.98it/s]
#  19%|█▊        | 614/3316 [05:16<22:44,  1.98it/s]
#  19%|█▊        | 615/3316 [05:17<22:36,  1.99it/s]
#  19%|█▊        | 616/3316 [05:17<22:37,  1.99it/s]
#  19%|█▊        | 617/3316 [05:18<22:29,  2.00it/s]
#  19%|█▊        | 618/3316 [05:18<22:34,  1.99it/s]
#  19%|█▊        | 619/3316 [05:19<22:37,  1.99it/s]
#  19%|█▊        | 620/3316 [05:19<22:39,  1.98it/s]
#  19%|█▊        | 621/3316 [05:20<22:37,  1.99it/s]
#  19%|█▉        | 622/3316 [05:20<22:36,  1.99it/s]
#  19%|█▉        | 623/3316 [05:21<22:35,  1.99it/s]
#  19%|█▉        | 624/3316 [05:21<22:39,  1.98it/s]
#  19%|█▉        | 625/3316 [05:22<22:38,  1.98it/s]
#  19%|█▉        | 626/3316 [05:22<22:32,  1.99it/s]
#  19%|█▉        | 627/3316 [05:23<22:31,  1.99it/s]
#  19%|█▉        | 628/3316 [05:23<22:29,  1.99it/s]
#  19%|█▉        | 629/3316 [05:24<22:29,  1.99it/s]
#  19%|█▉        | 630/3316 [05:24<22:24,  2.00it/s]
#  19%|█▉        | 631/3316 [05:25<22:32,  1.98it/s]
#  19%|█▉        | 632/3316 [05:25<22:44,  1.97it/s]
#  19%|█▉        | 633/3316 [05:26<22:37,  1.98it/s]
#  19%|█▉        | 634/3316 [05:26<22:37,  1.98it/s]
#  19%|█▉        | 635/3316 [05:27<22:37,  1.97it/s]
#  19%|█▉        | 636/3316 [05:27<22:27,  1.99it/s]
#  19%|█▉        | 637/3316 [05:28<22:36,  1.97it/s]
#  19%|█▉        | 638/3316 [05:28<22:29,  1.98it/s]
#  19%|█▉        | 639/3316 [05:29<22:28,  1.98it/s]
#  19%|█▉        | 640/3316 [05:29<22:37,  1.97it/s]
#  19%|█▉        | 641/3316 [05:30<22:34,  1.97it/s]
#  19%|█▉        | 642/3316 [05:30<22:29,  1.98it/s]
#  19%|█▉        | 643/3316 [05:31<22:30,  1.98it/s]
#  19%|█▉        | 644/3316 [05:31<22:30,  1.98it/s]
#  19%|█▉        | 645/3316 [05:32<22:33,  1.97it/s]
#  19%|█▉        | 646/3316 [05:32<22:23,  1.99it/s]
#  20%|█▉        | 647/3316 [05:33<22:14,  2.00it/s]
#  20%|█▉        | 648/3316 [05:33<22:15,  2.00it/s]
#  20%|█▉        | 649/3316 [05:34<22:18,  1.99it/s]
#  20%|█▉        | 650/3316 [05:34<22:18,  1.99it/s]
#  20%|█▉        | 651/3316 [05:35<22:12,  2.00it/s]
#  20%|█▉        | 652/3316 [05:35<22:16,  1.99it/s]
#  20%|█▉        | 653/3316 [05:36<22:15,  1.99it/s]
#  20%|█▉        | 654/3316 [05:36<22:09,  2.00it/s]
#  20%|█▉        | 655/3316 [05:37<22:04,  2.01it/s]
#  20%|█▉        | 656/3316 [05:37<22:07,  2.00it/s]
#  20%|█▉        | 657/3316 [05:38<22:11,  2.00it/s]
#  20%|█▉        | 658/3316 [05:38<22:17,  1.99it/s]
#  20%|█▉        | 659/3316 [05:39<22:17,  1.99it/s]
#  20%|█▉        | 660/3316 [05:39<22:16,  1.99it/s]
#  20%|█▉        | 661/3316 [05:40<22:11,  1.99it/s]
#  20%|█▉        | 662/3316 [05:40<22:06,  2.00it/s]
#  20%|█▉        | 663/3316 [05:41<22:02,  2.01it/s]
#  20%|██        | 664/3316 [05:41<22:02,  2.01it/s]
#  20%|██        | 665/3316 [05:42<22:08,  2.00it/s]
#  20%|██        | 666/3316 [05:42<22:10,  1.99it/s]
#  20%|██        | 667/3316 [05:43<22:17,  1.98it/s]
#  20%|██        | 668/3316 [05:43<22:13,  1.99it/s]
#  20%|██        | 669/3316 [05:44<22:14,  1.98it/s]
#  20%|██        | 670/3316 [05:44<22:13,  1.98it/s]
#  20%|██        | 671/3316 [05:45<22:10,  1.99it/s]
#  20%|██        | 672/3316 [05:45<22:09,  1.99it/s]
#  20%|██        | 673/3316 [05:46<22:20,  1.97it/s]
#  20%|██        | 674/3316 [05:46<22:32,  1.95it/s]
#  20%|██        | 675/3316 [05:47<22:41,  1.94it/s]
#  20%|██        | 676/3316 [05:47<22:43,  1.94it/s]
#  20%|██        | 677/3316 [05:48<22:39,  1.94it/s]
#  20%|██        | 678/3316 [05:48<22:39,  1.94it/s]
#  20%|██        | 679/3316 [05:49<22:29,  1.95it/s]
#  21%|██        | 680/3316 [05:49<22:23,  1.96it/s]
#  21%|██        | 681/3316 [05:50<22:16,  1.97it/s]
#  21%|██        | 682/3316 [05:50<22:12,  1.98it/s]
#  21%|██        | 683/3316 [05:51<22:21,  1.96it/s]
#  21%|██        | 684/3316 [05:51<22:15,  1.97it/s]
#  21%|██        | 685/3316 [05:52<22:13,  1.97it/s]
#  21%|██        | 686/3316 [05:52<22:03,  1.99it/s]
#  21%|██        | 687/3316 [05:53<22:05,  1.98it/s]
#  21%|██        | 688/3316 [05:53<21:57,  1.99it/s]
#  21%|██        | 689/3316 [05:54<21:58,  1.99it/s]
#  21%|██        | 690/3316 [05:54<22:02,  1.99it/s]
#  21%|██        | 691/3316 [05:55<22:03,  1.98it/s]
#  21%|██        | 692/3316 [05:55<22:03,  1.98it/s]
#  21%|██        | 693/3316 [05:56<22:01,  1.98it/s]
#  21%|██        | 694/3316 [05:56<22:00,  1.99it/s]
#  21%|██        | 695/3316 [05:57<22:01,  1.98it/s]
#  21%|██        | 696/3316 [05:57<22:00,  1.98it/s]
#  21%|██        | 697/3316 [05:58<21:58,  1.99it/s]
#  21%|██        | 698/3316 [05:58<21:56,  1.99it/s]
#  21%|██        | 699/3316 [05:59<21:56,  1.99it/s]
#  21%|██        | 700/3316 [05:59<21:49,  2.00it/s]
#  21%|██        | 701/3316 [06:00<21:48,  2.00it/s]
#  21%|██        | 702/3316 [06:00<21:51,  1.99it/s]
#  21%|██        | 703/3316 [06:01<21:54,  1.99it/s]
#  21%|██        | 704/3316 [06:01<21:47,  2.00it/s]
#  21%|██▏       | 705/3316 [06:02<22:01,  1.98it/s]
#  21%|██▏       | 706/3316 [06:03<21:57,  1.98it/s]
#  21%|██▏       | 707/3316 [06:03<21:54,  1.98it/s]
#  21%|██▏       | 708/3316 [06:04<22:00,  1.98it/s]
#  21%|██▏       | 709/3316 [06:04<22:00,  1.97it/s]
#  21%|██▏       | 710/3316 [06:05<22:04,  1.97it/s]
#  21%|██▏       | 711/3316 [06:05<22:11,  1.96it/s]
#  21%|██▏       | 712/3316 [06:06<22:07,  1.96it/s]
#  22%|██▏       | 713/3316 [06:06<22:20,  1.94it/s]
#  22%|██▏       | 714/3316 [06:07<22:18,  1.94it/s]
#  22%|██▏       | 715/3316 [06:07<22:26,  1.93it/s]
#  22%|██▏       | 716/3316 [06:08<22:27,  1.93it/s]
#  22%|██▏       | 717/3316 [06:08<22:23,  1.93it/s]
#  22%|██▏       | 718/3316 [06:09<22:24,  1.93it/s]
#  22%|██▏       | 719/3316 [06:09<22:09,  1.95it/s]
#  22%|██▏       | 720/3316 [06:10<22:06,  1.96it/s]
#  22%|██▏       | 721/3316 [06:10<22:09,  1.95it/s]
#  22%|██▏       | 722/3316 [06:11<21:58,  1.97it/s]
#  22%|██▏       | 723/3316 [06:11<21:49,  1.98it/s]
#  22%|██▏       | 724/3316 [06:12<21:50,  1.98it/s]
#  22%|██▏       | 725/3316 [06:12<21:45,  1.99it/s]
#  22%|██▏       | 726/3316 [06:13<21:47,  1.98it/s]
#  22%|██▏       | 727/3316 [06:13<21:48,  1.98it/s]
#  22%|██▏       | 728/3316 [06:14<21:39,  1.99it/s]
#  22%|██▏       | 729/3316 [06:14<21:42,  1.99it/s]
#  22%|██▏       | 730/3316 [06:15<21:39,  1.99it/s]
#  22%|██▏       | 731/3316 [06:15<21:44,  1.98it/s]
#  22%|██▏       | 732/3316 [06:16<21:42,  1.98it/s]
#  22%|██▏       | 733/3316 [06:16<21:51,  1.97it/s]
#  22%|██▏       | 734/3316 [06:17<21:46,  1.98it/s]
#  22%|██▏       | 735/3316 [06:17<21:48,  1.97it/s]
#  22%|██▏       | 736/3316 [06:18<21:46,  1.97it/s]
#  22%|██▏       | 737/3316 [06:18<21:39,  1.99it/s]
#  22%|██▏       | 738/3316 [06:19<21:40,  1.98it/s]
#  22%|██▏       | 739/3316 [06:19<21:40,  1.98it/s]
#  22%|██▏       | 740/3316 [06:20<21:40,  1.98it/s]
#  22%|██▏       | 741/3316 [06:20<21:37,  1.98it/s]
#  22%|██▏       | 742/3316 [06:21<21:37,  1.98it/s]
#  22%|██▏       | 743/3316 [06:21<21:42,  1.98it/s]
#  22%|██▏       | 744/3316 [06:22<21:38,  1.98it/s]
#  22%|██▏       | 745/3316 [06:22<21:37,  1.98it/s]
#  22%|██▏       | 746/3316 [06:23<21:39,  1.98it/s]
#  23%|██▎       | 747/3316 [06:23<21:43,  1.97it/s]
#  23%|██▎       | 748/3316 [06:24<22:00,  1.94it/s]
#  23%|██▎       | 749/3316 [06:24<21:53,  1.95it/s]
#  23%|██▎       | 750/3316 [06:25<21:59,  1.94it/s]
#  23%|██▎       | 751/3316 [06:25<21:57,  1.95it/s]
#  23%|██▎       | 752/3316 [06:26<22:01,  1.94it/s]
#  23%|██▎       | 753/3316 [06:26<21:53,  1.95it/s]
#  23%|██▎       | 754/3316 [06:27<21:49,  1.96it/s]
#  23%|██▎       | 755/3316 [06:27<21:43,  1.97it/s]
#  23%|██▎       | 756/3316 [06:28<21:38,  1.97it/s]
#  23%|██▎       | 757/3316 [06:28<21:45,  1.96it/s]
#  23%|██▎       | 758/3316 [06:29<21:39,  1.97it/s]
#  23%|██▎       | 759/3316 [06:29<21:40,  1.97it/s]
#  23%|██▎       | 760/3316 [06:30<21:35,  1.97it/s]
#  23%|██▎       | 761/3316 [06:30<21:41,  1.96it/s]
#  23%|██▎       | 762/3316 [06:31<21:38,  1.97it/s]
#  23%|██▎       | 763/3316 [06:31<21:29,  1.98it/s]
#  23%|██▎       | 764/3316 [06:32<21:26,  1.98it/s]
#  23%|██▎       | 765/3316 [06:32<21:23,  1.99it/s]
#  23%|██▎       | 766/3316 [06:33<21:29,  1.98it/s]
#  23%|██▎       | 767/3316 [06:34<21:28,  1.98it/s]
#  23%|██▎       | 768/3316 [06:34<21:24,  1.98it/s]
#  23%|██▎       | 769/3316 [06:35<21:27,  1.98it/s]
#  23%|██▎       | 770/3316 [06:35<21:19,  1.99it/s]
#  23%|██▎       | 771/3316 [06:36<21:17,  1.99it/s]
#  23%|██▎       | 772/3316 [06:36<21:10,  2.00it/s]
#  23%|██▎       | 773/3316 [06:37<21:18,  1.99it/s]
#  23%|██▎       | 774/3316 [06:37<21:18,  1.99it/s]
#  23%|██▎       | 775/3316 [06:38<21:19,  1.99it/s]
#  23%|██▎       | 776/3316 [06:38<21:19,  1.99it/s]
#  23%|██▎       | 777/3316 [06:39<21:22,  1.98it/s]
#  23%|██▎       | 778/3316 [06:39<21:22,  1.98it/s]
#  23%|██▎       | 779/3316 [06:40<21:30,  1.97it/s]
#  24%|██▎       | 780/3316 [06:40<21:26,  1.97it/s]
#  24%|██▎       | 781/3316 [06:41<21:23,  1.98it/s]
#  24%|██▎       | 782/3316 [06:41<21:30,  1.96it/s]
#  24%|██▎       | 783/3316 [06:42<21:31,  1.96it/s]
#  24%|██▎       | 784/3316 [06:42<21:28,  1.97it/s]
#  24%|██▎       | 785/3316 [06:43<21:37,  1.95it/s]
#  24%|██▎       | 786/3316 [06:43<21:45,  1.94it/s]
#  24%|██▎       | 787/3316 [06:44<21:38,  1.95it/s]
#  24%|██▍       | 788/3316 [06:44<21:29,  1.96it/s]
#  24%|██▍       | 789/3316 [06:45<21:25,  1.97it/s]
#  24%|██▍       | 790/3316 [06:45<21:20,  1.97it/s]
#  24%|██▍       | 791/3316 [06:46<21:32,  1.95it/s]
#  24%|██▍       | 792/3316 [06:46<21:25,  1.96it/s]
#  24%|██▍       | 793/3316 [06:47<21:30,  1.95it/s]
#  24%|██▍       | 794/3316 [06:47<21:28,  1.96it/s]
#  24%|██▍       | 795/3316 [06:48<21:27,  1.96it/s]
#  24%|██▍       | 796/3316 [06:48<21:17,  1.97it/s]
#  24%|██▍       | 797/3316 [06:49<21:24,  1.96it/s]
#  24%|██▍       | 798/3316 [06:49<21:21,  1.96it/s]
#  24%|██▍       | 799/3316 [06:50<21:20,  1.97it/s]
#  24%|██▍       | 800/3316 [06:50<21:18,  1.97it/s]
#  24%|██▍       | 801/3316 [06:51<21:14,  1.97it/s]
#  24%|██▍       | 802/3316 [06:51<21:14,  1.97it/s]
#  24%|██▍       | 803/3316 [06:52<21:06,  1.98it/s]
#  24%|██▍       | 804/3316 [06:52<21:13,  1.97it/s]
#  24%|██▍       | 805/3316 [06:53<21:06,  1.98it/s]
#  24%|██▍       | 806/3316 [06:53<21:11,  1.97it/s]
#  24%|██▍       | 807/3316 [06:54<21:09,  1.98it/s]
#  24%|██▍       | 808/3316 [06:54<21:10,  1.97it/s]
#  24%|██▍       | 809/3316 [06:55<21:16,  1.96it/s]
#  24%|██▍       | 810/3316 [06:55<21:05,  1.98it/s]
#  24%|██▍       | 811/3316 [06:56<21:08,  1.98it/s]
#  24%|██▍       | 812/3316 [06:56<20:59,  1.99it/s]
#  25%|██▍       | 813/3316 [06:57<20:58,  1.99it/s]
#  25%|██▍       | 814/3316 [06:57<20:51,  2.00it/s]
#  25%|██▍       | 815/3316 [06:58<20:53,  2.00it/s]
#  25%|██▍       | 816/3316 [06:58<21:03,  1.98it/s]
#  25%|██▍       | 817/3316 [06:59<21:12,  1.96it/s]
#  25%|██▍       | 818/3316 [06:59<21:09,  1.97it/s]
#  25%|██▍       | 819/3316 [07:00<21:20,  1.95it/s]
#  25%|██▍       | 820/3316 [07:00<21:18,  1.95it/s]
#  25%|██▍       | 821/3316 [07:01<21:04,  1.97it/s]
#  25%|██▍       | 822/3316 [07:01<21:04,  1.97it/s]
#  25%|██▍       | 823/3316 [07:02<21:03,  1.97it/s]
#  25%|██▍       | 824/3316 [07:02<21:09,  1.96it/s]
#  25%|██▍       | 825/3316 [07:03<21:05,  1.97it/s]
#  25%|██▍       | 826/3316 [07:03<21:27,  1.93it/s]
#  25%|██▍       | 827/3316 [07:04<21:24,  1.94it/s]
#  25%|██▍       | 828/3316 [07:05<21:21,  1.94it/s]
#  25%|██▌       | 829/3316 [07:05<21:30,  1.93it/s]
#  25%|██▌       | 830/3316 [07:06<21:17,  1.95it/s]
#  25%|██▌       | 831/3316 [07:06<21:18,  1.94it/s]
#  25%|██▌       | 832/3316 [07:07<21:22,  1.94it/s]
#  25%|██▌       | 833/3316 [07:07<21:14,  1.95it/s]
#  25%|██▌       | 834/3316 [07:08<21:08,  1.96it/s]
#  25%|██▌       | 835/3316 [07:08<21:02,  1.96it/s]
#  25%|██▌       | 836/3316 [07:09<21:00,  1.97it/s]
#  25%|██▌       | 837/3316 [07:09<21:02,  1.96it/s]
#  25%|██▌       | 838/3316 [07:10<20:58,  1.97it/s]
#  25%|██▌       | 839/3316 [07:10<21:01,  1.96it/s]
#  25%|██▌       | 840/3316 [07:11<20:53,  1.98it/s]
#  25%|██▌       | 841/3316 [07:11<20:52,  1.98it/s]
#  25%|██▌       | 842/3316 [07:12<20:52,  1.97it/s]
#  25%|██▌       | 843/3316 [07:12<20:48,  1.98it/s]
#  25%|██▌       | 844/3316 [07:13<20:52,  1.97it/s]
#  25%|██▌       | 845/3316 [07:13<20:51,  1.97it/s]
#  26%|██▌       | 846/3316 [07:14<20:48,  1.98it/s]
#  26%|██▌       | 847/3316 [07:14<20:43,  1.98it/s]
#  26%|██▌       | 848/3316 [07:15<20:37,  1.99it/s]
#  26%|██▌       | 849/3316 [07:15<20:36,  2.00it/s]
#  26%|██▌       | 850/3316 [07:16<20:35,  2.00it/s]
#  26%|██▌       | 851/3316 [07:16<20:40,  1.99it/s]
#  26%|██▌       | 852/3316 [07:17<20:42,  1.98it/s]
#  26%|██▌       | 853/3316 [07:17<20:44,  1.98it/s]
#  26%|██▌       | 854/3316 [07:18<20:43,  1.98it/s]
#  26%|██▌       | 855/3316 [07:18<20:47,  1.97it/s]
#  26%|██▌       | 856/3316 [07:19<20:46,  1.97it/s]
#  26%|██▌       | 857/3316 [07:19<20:55,  1.96it/s]
#  26%|██▌       | 858/3316 [07:20<20:51,  1.96it/s]
#  26%|██▌       | 859/3316 [07:20<20:49,  1.97it/s]
#  26%|██▌       | 860/3316 [07:21<20:47,  1.97it/s]
#  26%|██▌       | 861/3316 [07:21<21:00,  1.95it/s]
#  26%|██▌       | 862/3316 [07:22<20:49,  1.96it/s]
#  26%|██▌       | 863/3316 [07:22<20:50,  1.96it/s]
#  26%|██▌       | 864/3316 [07:23<20:53,  1.96it/s]
#  26%|██▌       | 865/3316 [07:23<20:58,  1.95it/s]
#  26%|██▌       | 866/3316 [07:24<21:11,  1.93it/s]
#  26%|██▌       | 867/3316 [07:24<20:58,  1.95it/s]
#  26%|██▌       | 868/3316 [07:25<21:02,  1.94it/s]
#  26%|██▌       | 869/3316 [07:25<20:49,  1.96it/s]
#  26%|██▌       | 870/3316 [07:26<20:38,  1.98it/s]
#  26%|██▋       | 871/3316 [07:26<20:39,  1.97it/s]
#  26%|██▋       | 872/3316 [07:27<20:38,  1.97it/s]
#  26%|██▋       | 873/3316 [07:27<20:31,  1.98it/s]
#  26%|██▋       | 874/3316 [07:28<20:29,  1.99it/s]
#  26%|██▋       | 875/3316 [07:28<20:27,  1.99it/s]
#  26%|██▋       | 876/3316 [07:29<20:30,  1.98it/s]
#  26%|██▋       | 877/3316 [07:29<20:26,  1.99it/s]
#  26%|██▋       | 878/3316 [07:30<20:30,  1.98it/s]
#  27%|██▋       | 879/3316 [07:30<20:29,  1.98it/s]
#  27%|██▋       | 880/3316 [07:31<20:23,  1.99it/s]
#  27%|██▋       | 881/3316 [07:31<20:30,  1.98it/s]
#  27%|██▋       | 882/3316 [07:32<20:28,  1.98it/s]
#  27%|██▋       | 883/3316 [07:32<20:31,  1.98it/s]
#  27%|██▋       | 884/3316 [07:33<20:24,  1.99it/s]
#  27%|██▋       | 885/3316 [07:33<20:26,  1.98it/s]
#  27%|██▋       | 886/3316 [07:34<20:25,  1.98it/s]
#  27%|██▋       | 887/3316 [07:34<20:21,  1.99it/s]
#  27%|██▋       | 888/3316 [07:35<20:22,  1.99it/s]
#  27%|██▋       | 889/3316 [07:35<20:17,  1.99it/s]
#  27%|██▋       | 890/3316 [07:36<20:12,  2.00it/s]
#  27%|██▋       | 891/3316 [07:36<20:29,  1.97it/s]
#  27%|██▋       | 892/3316 [07:37<20:36,  1.96it/s]
#  27%|██▋       | 893/3316 [07:37<20:28,  1.97it/s]
#  27%|██▋       | 894/3316 [07:38<20:37,  1.96it/s]
#  27%|██▋       | 895/3316 [07:38<20:43,  1.95it/s]
#  27%|██▋       | 896/3316 [07:39<20:38,  1.95it/s]
#  27%|██▋       | 897/3316 [07:40<20:47,  1.94it/s]
#  27%|██▋       | 898/3316 [07:40<20:59,  1.92it/s]
#  27%|██▋       | 899/3316 [07:41<20:49,  1.93it/s]
#  27%|██▋       | 900/3316 [07:41<20:43,  1.94it/s]
#  27%|██▋       | 901/3316 [07:42<20:33,  1.96it/s]
#  27%|██▋       | 902/3316 [07:42<20:40,  1.95it/s]
#  27%|██▋       | 903/3316 [07:43<20:30,  1.96it/s]
#  27%|██▋       | 904/3316 [07:43<20:25,  1.97it/s]
#  27%|██▋       | 905/3316 [07:44<20:27,  1.96it/s]
#  27%|██▋       | 906/3316 [07:44<20:21,  1.97it/s]
#  27%|██▋       | 907/3316 [07:45<20:22,  1.97it/s]
#  27%|██▋       | 908/3316 [07:45<20:20,  1.97it/s]
#  27%|██▋       | 909/3316 [07:46<20:15,  1.98it/s]
#  27%|██▋       | 910/3316 [07:46<20:09,  1.99it/s]
#  27%|██▋       | 911/3316 [07:47<20:13,  1.98it/s]
#  28%|██▊       | 912/3316 [07:47<20:17,  1.97it/s]
#  28%|██▊       | 913/3316 [07:48<20:16,  1.97it/s]
#  28%|██▊       | 914/3316 [07:48<20:10,  1.98it/s]
#  28%|██▊       | 915/3316 [07:49<20:09,  1.99it/s]
#  28%|██▊       | 916/3316 [07:49<20:07,  1.99it/s]
#  28%|██▊       | 917/3316 [07:50<20:05,  1.99it/s]
#  28%|██▊       | 918/3316 [07:50<20:11,  1.98it/s]
#  28%|██▊       | 919/3316 [07:51<20:12,  1.98it/s]
#  28%|██▊       | 920/3316 [07:51<20:07,  1.98it/s]
#  28%|██▊       | 921/3316 [07:52<20:03,  1.99it/s]
#  28%|██▊       | 922/3316 [07:52<20:04,  1.99it/s]
#  28%|██▊       | 923/3316 [07:53<20:05,  1.99it/s]
#  28%|██▊       | 924/3316 [07:53<20:04,  1.99it/s]
#  28%|██▊       | 925/3316 [07:54<20:03,  1.99it/s]
#  28%|██▊       | 926/3316 [07:54<20:03,  1.99it/s]
#  28%|██▊       | 927/3316 [07:55<20:00,  1.99it/s]
#  28%|██▊       | 928/3316 [07:55<20:10,  1.97it/s]
#  28%|██▊       | 929/3316 [07:56<20:10,  1.97it/s]
#  28%|██▊       | 930/3316 [07:56<20:24,  1.95it/s]
#  28%|██▊       | 931/3316 [07:57<20:13,  1.97it/s]
#  28%|██▊       | 932/3316 [07:57<20:06,  1.98it/s]
#  28%|██▊       | 933/3316 [07:58<20:03,  1.98it/s]
#  28%|██▊       | 934/3316 [07:58<20:10,  1.97it/s]
#  28%|██▊       | 935/3316 [07:59<20:14,  1.96it/s]
#  28%|██▊       | 936/3316 [07:59<20:09,  1.97it/s]
#  28%|██▊       | 937/3316 [08:00<20:05,  1.97it/s]
#  28%|██▊       | 938/3316 [08:00<20:09,  1.97it/s]
#  28%|██▊       | 939/3316 [08:01<20:14,  1.96it/s]
#  28%|██▊       | 940/3316 [08:01<20:17,  1.95it/s]
#  28%|██▊       | 941/3316 [08:02<20:14,  1.95it/s]
# ...
#  91%|█████████ | 3012/3316 [25:32<02:34,  1.97it/s]
#  91%|█████████ | 3013/3316 [25:33<02:35,  1.95it/s]
#  91%|█████████ | 3014/3316 [25:33<02:35,  1.94it/s]
#  91%|█████████ | 3015/3316 [25:34<02:35,  1.93it/s]
#  91%|█████████ | 3016/3316 [25:34<02:33,  1.95it/s]
#  91%|█████████ | 3017/3316 [25:35<02:32,  1.96it/s]
#  91%|█████████ | 3018/3316 [25:35<02:31,  1.97it/s]
#  91%|█████████ | 3019/3316 [25:36<02:30,  1.97it/s]
#  91%|█████████ | 3020/3316 [25:36<02:29,  1.99it/s]
#  91%|█████████ | 3021/3316 [25:37<02:28,  1.98it/s]
#  91%|█████████ | 3022/3316 [25:37<02:27,  1.99it/s]
#  91%|█████████ | 3023/3316 [25:38<02:27,  1.98it/s]
#  91%|█████████ | 3024/3316 [25:38<02:28,  1.97it/s]
#  91%|█████████ | 3025/3316 [25:39<02:27,  1.98it/s]
#  91%|█████████▏| 3026/3316 [25:39<02:26,  1.98it/s]
#  91%|█████████▏| 3027/3316 [25:40<02:26,  1.97it/s]
#  91%|█████████▏| 3028/3316 [25:40<02:26,  1.96it/s]
#  91%|█████████▏| 3029/3316 [25:41<02:27,  1.95it/s]
#  91%|█████████▏| 3030/3316 [25:41<02:25,  1.96it/s]
#  91%|█████████▏| 3031/3316 [25:42<02:24,  1.97it/s]
#  91%|█████████▏| 3032/3316 [25:42<02:23,  1.97it/s]
#  91%|█████████▏| 3033/3316 [25:43<02:23,  1.97it/s]
#  91%|█████████▏| 3034/3316 [25:43<02:24,  1.95it/s]
#  92%|█████████▏| 3035/3316 [25:44<02:22,  1.97it/s]
#  92%|█████████▏| 3036/3316 [25:44<02:21,  1.98it/s]
#  92%|█████████▏| 3037/3316 [25:45<02:20,  1.99it/s]
#  92%|█████████▏| 3038/3316 [25:45<02:19,  2.00it/s]
#  92%|█████████▏| 3039/3316 [25:46<02:18,  2.01it/s]
#  92%|█████████▏| 3040/3316 [25:46<02:19,  1.97it/s]
#  92%|█████████▏| 3041/3316 [25:47<02:19,  1.98it/s]
#  92%|█████████▏| 3042/3316 [25:47<02:17,  1.99it/s]
#  92%|█████████▏| 3043/3316 [25:48<02:17,  1.99it/s]
#  92%|█████████▏| 3044/3316 [25:48<02:16,  1.99it/s]
#  92%|█████████▏| 3045/3316 [25:49<02:18,  1.96it/s]
#  92%|█████████▏| 3046/3316 [25:49<02:17,  1.97it/s]
#  92%|█████████▏| 3047/3316 [25:50<02:18,  1.95it/s]
#  92%|█████████▏| 3048/3316 [25:50<02:16,  1.96it/s]
#  92%|█████████▏| 3049/3316 [25:51<02:17,  1.94it/s]
#  92%|█████████▏| 3050/3316 [25:52<02:17,  1.94it/s]
#  92%|█████████▏| 3051/3316 [25:52<02:15,  1.96it/s]
#  92%|█████████▏| 3052/3316 [25:53<02:14,  1.96it/s]
#  92%|█████████▏| 3053/3316 [25:53<02:13,  1.97it/s]
#  92%|█████████▏| 3054/3316 [25:54<02:14,  1.95it/s]
#  92%|█████████▏| 3055/3316 [25:54<02:13,  1.95it/s]
#  92%|█████████▏| 3056/3316 [25:55<02:13,  1.95it/s]
#  92%|█████████▏| 3057/3316 [25:55<02:12,  1.96it/s]
#  92%|█████████▏| 3058/3316 [25:56<02:11,  1.96it/s]
#  92%|█████████▏| 3059/3316 [25:56<02:10,  1.97it/s]
#  92%|█████████▏| 3060/3316 [25:57<02:10,  1.97it/s]
#  92%|█████████▏| 3061/3316 [25:57<02:08,  1.98it/s]
#  92%|█████████▏| 3062/3316 [25:58<02:09,  1.97it/s]
#  92%|█████████▏| 3063/3316 [25:58<02:08,  1.98it/s]
#  92%|█████████▏| 3064/3316 [25:59<02:08,  1.96it/s]
#  92%|█████████▏| 3065/3316 [25:59<02:07,  1.97it/s]
#  92%|█████████▏| 3066/3316 [26:00<02:07,  1.96it/s]
#  92%|█████████▏| 3067/3316 [26:00<02:05,  1.98it/s]
#  93%|█████████▎| 3068/3316 [26:01<02:04,  1.99it/s]
#  93%|█████████▎| 3069/3316 [26:01<02:04,  1.99it/s]
#  93%|█████████▎| 3070/3316 [26:02<02:03,  1.99it/s]
#  93%|█████████▎| 3071/3316 [26:02<02:04,  1.97it/s]
#  93%|█████████▎| 3072/3316 [26:03<02:03,  1.97it/s]
#  93%|█████████▎| 3073/3316 [26:03<02:02,  1.98it/s]
#  93%|█████████▎| 3074/3316 [26:04<02:01,  1.99it/s]
#  93%|█████████▎| 3075/3316 [26:04<02:01,  1.99it/s]
#  93%|█████████▎| 3076/3316 [26:05<02:01,  1.97it/s]
#  93%|█████████▎| 3077/3316 [26:05<02:00,  1.99it/s]
#  93%|█████████▎| 3078/3316 [26:06<02:00,  1.97it/s]
#  93%|█████████▎| 3079/3316 [26:06<02:00,  1.97it/s]
#  93%|█████████▎| 3080/3316 [26:07<01:59,  1.97it/s]
#  93%|█████████▎| 3081/3316 [26:07<01:59,  1.96it/s]
#  93%|█████████▎| 3082/3316 [26:08<01:58,  1.97it/s]
#  93%|█████████▎| 3083/3316 [26:08<01:57,  1.98it/s]
#  93%|█████████▎| 3084/3316 [26:09<01:57,  1.97it/s]
#  93%|█████████▎| 3085/3316 [26:09<01:58,  1.95it/s]
#  93%|█████████▎| 3086/3316 [26:10<01:57,  1.96it/s]
#  93%|█████████▎| 3087/3316 [26:10<01:56,  1.97it/s]
#  93%|█████████▎| 3088/3316 [26:11<01:56,  1.96it/s]
#  93%|█████████▎| 3089/3316 [26:11<01:55,  1.97it/s]
#  93%|█████████▎| 3090/3316 [26:12<01:56,  1.94it/s]
#  93%|█████████▎| 3091/3316 [26:12<01:55,  1.95it/s]
#  93%|█████████▎| 3092/3316 [26:13<01:54,  1.95it/s]
#  93%|█████████▎| 3093/3316 [26:13<01:54,  1.96it/s]
#  93%|█████████▎| 3094/3316 [26:14<01:54,  1.94it/s]
#  93%|█████████▎| 3095/3316 [26:14<01:54,  1.94it/s]
#  93%|█████████▎| 3096/3316 [26:15<01:53,  1.95it/s]
#  93%|█████████▎| 3097/3316 [26:15<01:52,  1.94it/s]
#  93%|█████████▎| 3098/3316 [26:16<01:52,  1.93it/s]
#  93%|█████████▎| 3099/3316 [26:16<01:51,  1.95it/s]
#  93%|█████████▎| 3100/3316 [26:17<01:49,  1.97it/s]
#  94%|█████████▎| 3101/3316 [26:17<01:48,  1.98it/s]
#  94%|█████████▎| 3102/3316 [26:18<01:47,  1.98it/s]
#  94%|█████████▎| 3103/3316 [26:18<01:48,  1.97it/s]
#  94%|█████████▎| 3104/3316 [26:19<01:47,  1.97it/s]
#  94%|█████████▎| 3105/3316 [26:19<01:48,  1.95it/s]
#  94%|█████████▎| 3106/3316 [26:20<01:46,  1.97it/s]
#  94%|█████████▎| 3107/3316 [26:20<01:45,  1.99it/s]
#  94%|█████████▎| 3108/3316 [26:21<01:44,  1.99it/s]
#  94%|█████████▍| 3109/3316 [26:21<01:44,  1.98it/s]
#  94%|█████████▍| 3110/3316 [26:22<01:43,  1.99it/s]
#  94%|█████████▍| 3111/3316 [26:23<01:44,  1.97it/s]
#  94%|█████████▍| 3112/3316 [26:23<01:43,  1.98it/s]
#  94%|█████████▍| 3113/3316 [26:24<01:42,  1.98it/s]
#  94%|█████████▍| 3114/3316 [26:24<01:42,  1.98it/s]
#  94%|█████████▍| 3115/3316 [26:25<01:41,  1.98it/s]
#  94%|█████████▍| 3116/3316 [26:25<01:42,  1.96it/s]
#  94%|█████████▍| 3117/3316 [26:26<01:42,  1.95it/s]
#  94%|█████████▍| 3118/3316 [26:26<01:41,  1.96it/s]
#  94%|█████████▍| 3119/3316 [26:27<01:42,  1.93it/s]
#  94%|█████████▍| 3120/3316 [26:27<01:41,  1.92it/s]
#  94%|█████████▍| 3121/3316 [26:28<01:40,  1.94it/s]
#  94%|█████████▍| 3122/3316 [26:28<01:40,  1.94it/s]
#  94%|█████████▍| 3123/3316 [26:29<01:39,  1.95it/s]
#  94%|█████████▍| 3124/3316 [26:29<01:39,  1.93it/s]
#  94%|█████████▍| 3125/3316 [26:30<01:38,  1.94it/s]
#  94%|█████████▍| 3126/3316 [26:30<01:38,  1.93it/s]
#  94%|█████████▍| 3127/3316 [26:31<01:38,  1.92it/s]
#  94%|█████████▍| 3128/3316 [26:31<01:39,  1.90it/s]
#  94%|█████████▍| 3129/3316 [26:32<01:38,  1.90it/s]
#  94%|█████████▍| 3130/3316 [26:32<01:36,  1.92it/s]
#  94%|█████████▍| 3131/3316 [26:33<01:34,  1.95it/s]
#  94%|█████████▍| 3132/3316 [26:33<01:34,  1.95it/s]
#  94%|█████████▍| 3133/3316 [26:34<01:32,  1.97it/s]
#  95%|█████████▍| 3134/3316 [26:34<01:33,  1.96it/s]
#  95%|█████████▍| 3135/3316 [26:35<01:32,  1.95it/s]
#  95%|█████████▍| 3136/3316 [26:35<01:32,  1.95it/s]
#  95%|█████████▍| 3137/3316 [26:36<01:32,  1.94it/s]
#  95%|█████████▍| 3138/3316 [26:36<01:31,  1.96it/s]
#  95%|█████████▍| 3139/3316 [26:37<01:29,  1.97it/s]
#  95%|█████████▍| 3140/3316 [26:37<01:29,  1.98it/s]
#  95%|█████████▍| 3141/3316 [26:38<01:29,  1.97it/s]
#  95%|█████████▍| 3142/3316 [26:38<01:27,  1.98it/s]
#  95%|█████████▍| 3143/3316 [26:39<01:27,  1.98it/s]
#  95%|█████████▍| 3144/3316 [26:39<01:26,  1.99it/s]
#  95%|█████████▍| 3145/3316 [26:40<01:26,  1.98it/s]
#  95%|█████████▍| 3146/3316 [26:40<01:26,  1.97it/s]
#  95%|█████████▍| 3147/3316 [26:41<01:25,  1.98it/s]
#  95%|█████████▍| 3148/3316 [26:41<01:24,  1.99it/s]
#  95%|█████████▍| 3149/3316 [26:42<01:23,  1.99it/s]
#  95%|█████████▍| 3150/3316 [26:42<01:23,  1.99it/s]
#  95%|█████████▌| 3151/3316 [26:43<01:23,  1.96it/s]
#  95%|█████████▌| 3152/3316 [26:43<01:23,  1.96it/s]
#  95%|█████████▌| 3153/3316 [26:44<01:22,  1.97it/s]
#  95%|█████████▌| 3154/3316 [26:44<01:22,  1.97it/s]
#  95%|█████████▌| 3155/3316 [26:45<01:21,  1.97it/s]
#  95%|█████████▌| 3156/3316 [26:46<01:21,  1.97it/s]
#  95%|█████████▌| 3157/3316 [26:46<01:20,  1.97it/s]
#  95%|█████████▌| 3158/3316 [26:47<01:19,  1.98it/s]
#  95%|█████████▌| 3159/3316 [26:47<01:20,  1.95it/s]
#  95%|█████████▌| 3160/3316 [26:48<01:19,  1.96it/s]
#  95%|█████████▌| 3161/3316 [26:48<01:20,  1.93it/s]
#  95%|█████████▌| 3162/3316 [26:49<01:19,  1.94it/s]
#  95%|█████████▌| 3163/3316 [26:49<01:19,  1.94it/s]
#  95%|█████████▌| 3164/3316 [26:50<01:18,  1.95it/s]
#  95%|█████████▌| 3165/3316 [26:50<01:18,  1.94it/s]
#  95%|█████████▌| 3166/3316 [26:51<01:16,  1.95it/s]
#  96%|█████████▌| 3167/3316 [26:51<01:15,  1.97it/s]
#  96%|█████████▌| 3168/3316 [26:52<01:14,  1.98it/s]
#  96%|█████████▌| 3169/3316 [26:52<01:14,  1.98it/s]
#  96%|█████████▌| 3170/3316 [26:53<01:13,  1.99it/s]
#  96%|█████████▌| 3171/3316 [26:53<01:12,  2.00it/s]
#  96%|█████████▌| 3172/3316 [26:54<01:12,  1.98it/s]
#  96%|█████████▌| 3173/3316 [26:54<01:12,  1.98it/s]
#  96%|█████████▌| 3174/3316 [26:55<01:12,  1.97it/s]
#  96%|█████████▌| 3175/3316 [26:55<01:11,  1.98it/s]
#  96%|█████████▌| 3176/3316 [26:56<01:10,  1.99it/s]
#  96%|█████████▌| 3177/3316 [26:56<01:10,  1.98it/s]
#  96%|█████████▌| 3178/3316 [26:57<01:10,  1.97it/s]
#  96%|█████████▌| 3179/3316 [26:57<01:10,  1.95it/s]
#  96%|█████████▌| 3180/3316 [26:58<01:08,  1.97it/s]
#  96%|█████████▌| 3181/3316 [26:58<01:08,  1.97it/s]
#  96%|█████████▌| 3182/3316 [26:59<01:07,  1.98it/s]
#  96%|█████████▌| 3183/3316 [26:59<01:07,  1.98it/s]
#  96%|█████████▌| 3184/3316 [27:00<01:06,  1.99it/s]
#  96%|█████████▌| 3185/3316 [27:00<01:06,  1.97it/s]
#  96%|█████████▌| 3186/3316 [27:01<01:05,  1.98it/s]
#  96%|█████████▌| 3187/3316 [27:01<01:04,  1.99it/s]
#  96%|█████████▌| 3188/3316 [27:02<01:05,  1.96it/s]
#  96%|█████████▌| 3189/3316 [27:02<01:04,  1.96it/s]
#  96%|█████████▌| 3190/3316 [27:03<01:04,  1.96it/s]
#  96%|█████████▌| 3191/3316 [27:03<01:04,  1.95it/s]
#  96%|█████████▋| 3192/3316 [27:04<01:04,  1.92it/s]
#  96%|█████████▋| 3193/3316 [27:04<01:03,  1.93it/s]
#  96%|█████████▋| 3194/3316 [27:05<01:02,  1.95it/s]
#  96%|█████████▋| 3195/3316 [27:05<01:03,  1.92it/s]
#  96%|█████████▋| 3196/3316 [27:06<01:02,  1.93it/s]
#  96%|█████████▋| 3197/3316 [27:06<01:01,  1.93it/s]
#  96%|█████████▋| 3198/3316 [27:07<01:00,  1.94it/s]
#  96%|█████████▋| 3199/3316 [27:07<00:59,  1.96it/s]
#  97%|█████████▋| 3200/3316 [27:08<00:59,  1.96it/s]
#  97%|█████████▋| 3201/3316 [27:08<00:58,  1.95it/s]
#  97%|█████████▋| 3202/3316 [27:09<00:58,  1.96it/s]
#  97%|█████████▋| 3203/3316 [27:09<00:57,  1.96it/s]
#  97%|█████████▋| 3204/3316 [27:10<00:57,  1.96it/s]
#  97%|█████████▋| 3205/3316 [27:10<00:56,  1.97it/s]
#  97%|█████████▋| 3206/3316 [27:11<00:55,  1.97it/s]
#  97%|█████████▋| 3207/3316 [27:11<00:55,  1.98it/s]
#  97%|█████████▋| 3208/3316 [27:12<00:54,  1.98it/s]
#  97%|█████████▋| 3209/3316 [27:13<00:53,  1.98it/s]
#  97%|█████████▋| 3210/3316 [27:13<00:53,  1.98it/s]
#  97%|█████████▋| 3211/3316 [27:14<00:53,  1.97it/s]
#  97%|█████████▋| 3212/3316 [27:14<00:52,  1.99it/s]
#  97%|█████████▋| 3213/3316 [27:15<00:52,  1.96it/s]
#  97%|█████████▋| 3214/3316 [27:15<00:51,  1.98it/s]
#  97%|█████████▋| 3215/3316 [27:16<00:51,  1.96it/s]
#  97%|█████████▋| 3216/3316 [27:16<00:50,  1.97it/s]
#  97%|█████████▋| 3217/3316 [27:17<00:50,  1.95it/s]
#  97%|█████████▋| 3218/3316 [27:17<00:50,  1.95it/s]
#  97%|█████████▋| 3219/3316 [27:18<00:49,  1.97it/s]
#  97%|█████████▋| 3220/3316 [27:18<00:48,  1.97it/s]
#  97%|█████████▋| 3221/3316 [27:19<00:48,  1.95it/s]
#  97%|█████████▋| 3222/3316 [27:19<00:48,  1.94it/s]
#  97%|█████████▋| 3223/3316 [27:20<00:47,  1.96it/s]
#  97%|█████████▋| 3224/3316 [27:20<00:46,  1.97it/s]
#  97%|█████████▋| 3225/3316 [27:21<00:46,  1.98it/s]
#  97%|█████████▋| 3226/3316 [27:21<00:45,  1.98it/s]
#  97%|█████████▋| 3227/3316 [27:22<00:45,  1.97it/s]
#  97%|█████████▋| 3228/3316 [27:22<00:44,  1.96it/s]
#  97%|█████████▋| 3229/3316 [27:23<00:44,  1.96it/s]
#  97%|█████████▋| 3230/3316 [27:23<00:44,  1.95it/s]
#  97%|█████████▋| 3231/3316 [27:24<00:43,  1.94it/s]
#  97%|█████████▋| 3232/3316 [27:24<00:43,  1.94it/s]
#  97%|█████████▋| 3233/3316 [27:25<00:42,  1.95it/s]
#  98%|█████████▊| 3234/3316 [27:25<00:42,  1.95it/s]
#  98%|█████████▊| 3235/3316 [27:26<00:41,  1.95it/s]
#  98%|█████████▊| 3236/3316 [27:26<00:40,  1.95it/s]
#  98%|█████████▊| 3237/3316 [27:27<00:40,  1.93it/s]
#  98%|█████████▊| 3238/3316 [27:27<00:40,  1.92it/s]
#  98%|█████████▊| 3239/3316 [27:28<00:39,  1.94it/s]
#  98%|█████████▊| 3240/3316 [27:28<00:39,  1.95it/s]
#  98%|█████████▊| 3241/3316 [27:29<00:38,  1.96it/s]
#  98%|█████████▊| 3242/3316 [27:29<00:37,  1.97it/s]
#  98%|█████████▊| 3243/3316 [27:30<00:36,  1.99it/s]
#  98%|█████████▊| 3244/3316 [27:30<00:36,  1.98it/s]
#  98%|█████████▊| 3245/3316 [27:31<00:36,  1.97it/s]
#  98%|█████████▊| 3246/3316 [27:31<00:35,  1.95it/s]
#  98%|█████████▊| 3247/3316 [27:32<00:35,  1.94it/s]
#  98%|█████████▊| 3248/3316 [27:32<00:34,  1.96it/s]
#  98%|█████████▊| 3249/3316 [27:33<00:34,  1.97it/s]
#  98%|█████████▊| 3250/3316 [27:33<00:33,  1.96it/s]
#  98%|█████████▊| 3251/3316 [27:34<00:33,  1.96it/s]
#  98%|█████████▊| 3252/3316 [27:34<00:32,  1.97it/s]
#  98%|█████████▊| 3253/3316 [27:35<00:31,  1.97it/s]
#  98%|█████████▊| 3254/3316 [27:35<00:31,  1.97it/s]
#  98%|█████████▊| 3255/3316 [27:36<00:30,  1.98it/s]
#  98%|█████████▊| 3256/3316 [27:36<00:30,  1.99it/s]
#  98%|█████████▊| 3257/3316 [27:37<00:29,  1.98it/s]
#  98%|█████████▊| 3258/3316 [27:37<00:29,  1.99it/s]
#  98%|█████████▊| 3259/3316 [27:38<00:28,  1.97it/s]
#  98%|█████████▊| 3260/3316 [27:38<00:28,  1.98it/s]
#  98%|█████████▊| 3261/3316 [27:39<00:27,  1.97it/s]
#  98%|█████████▊| 3262/3316 [27:40<00:27,  1.94it/s]
#  98%|█████████▊| 3263/3316 [27:40<00:27,  1.96it/s]
#  98%|█████████▊| 3264/3316 [27:41<00:26,  1.94it/s]
#  98%|█████████▊| 3265/3316 [27:41<00:26,  1.96it/s]
#  98%|█████████▊| 3266/3316 [27:42<00:25,  1.97it/s]
#  99%|█████████▊| 3267/3316 [27:42<00:24,  1.96it/s]
#  99%|█████████▊| 3268/3316 [27:43<00:24,  1.96it/s]
#  99%|█████████▊| 3269/3316 [27:43<00:24,  1.90it/s]
#  99%|█████████▊| 3270/3316 [27:44<00:24,  1.88it/s]
#  99%|█████████▊| 3271/3316 [27:44<00:23,  1.91it/s]
#  99%|█████████▊| 3272/3316 [27:45<00:22,  1.92it/s]
#  99%|█████████▊| 3273/3316 [27:45<00:22,  1.94it/s]
#  99%|█████████▊| 3274/3316 [27:46<00:21,  1.93it/s]
#  99%|█████████▉| 3275/3316 [27:46<00:21,  1.95it/s]
#  99%|█████████▉| 3276/3316 [27:47<00:20,  1.96it/s]
#  99%|█████████▉| 3277/3316 [27:47<00:19,  1.97it/s]
#  99%|█████████▉| 3278/3316 [27:48<00:19,  1.98it/s]
#  99%|█████████▉| 3279/3316 [27:48<00:18,  1.98it/s]
#  99%|█████████▉| 3280/3316 [27:49<00:18,  1.97it/s]
#  99%|█████████▉| 3281/3316 [27:49<00:17,  1.96it/s]
#  99%|█████████▉| 3282/3316 [27:50<00:17,  1.97it/s]
#  99%|█████████▉| 3283/3316 [27:50<00:16,  1.95it/s]
#  99%|█████████▉| 3284/3316 [27:51<00:16,  1.95it/s]
#  99%|█████████▉| 3285/3316 [27:51<00:15,  1.97it/s]
#  99%|█████████▉| 3286/3316 [27:52<00:15,  1.98it/s]
#  99%|█████████▉| 3287/3316 [27:52<00:14,  1.99it/s]
#  99%|█████████▉| 3288/3316 [27:53<00:14,  1.99it/s]
#  99%|█████████▉| 3289/3316 [27:53<00:13,  2.00it/s]
#  99%|█████████▉| 3290/3316 [27:54<00:13,  1.98it/s]
#  99%|█████████▉| 3291/3316 [27:54<00:12,  1.97it/s]
#  99%|█████████▉| 3292/3316 [27:55<00:12,  1.98it/s]
#  99%|█████████▉| 3293/3316 [27:55<00:11,  1.96it/s]
#  99%|█████████▉| 3294/3316 [27:56<00:11,  1.97it/s]
#  99%|█████████▉| 3295/3316 [27:56<00:10,  1.96it/s]
#  99%|█████████▉| 3296/3316 [27:57<00:10,  1.97it/s]
#  99%|█████████▉| 3297/3316 [27:57<00:09,  1.97it/s]
#  99%|█████████▉| 3298/3316 [27:58<00:09,  1.97it/s]
#  99%|█████████▉| 3299/3316 [27:58<00:08,  1.97it/s]
# 100%|█████████▉| 3300/3316 [27:59<00:08,  1.96it/s]
# 100%|█████████▉| 3301/3316 [27:59<00:07,  1.97it/s]
# 100%|█████████▉| 3302/3316 [28:00<00:07,  1.95it/s]
# 100%|█████████▉| 3303/3316 [28:00<00:06,  1.93it/s]
# 100%|█████████▉| 3304/3316 [28:01<00:06,  1.94it/s]
# 100%|█████████▉| 3305/3316 [28:01<00:05,  1.95it/s]
# 100%|█████████▉| 3306/3316 [28:02<00:05,  1.93it/s]
# 100%|█████████▉| 3307/3316 [28:03<00:04,  1.93it/s]
# 100%|█████████▉| 3308/3316 [28:03<00:04,  1.95it/s]
# 100%|█████████▉| 3309/3316 [28:04<00:03,  1.96it/s]
# 100%|█████████▉| 3310/3316 [28:04<00:03,  1.96it/s]
# 100%|█████████▉| 3311/3316 [28:05<00:02,  1.98it/s]
# 100%|█████████▉| 3312/3316 [28:05<00:02,  1.98it/s]
# 100%|█████████▉| 3313/3316 [28:06<00:01,  1.99it/s]
# 100%|█████████▉| 3314/3316 [28:06<00:01,  2.00it/s]
# 100%|█████████▉| 3315/3316 [28:07<00:00,  2.00it/s]
# 100%|██████████| 3316/3316 [28:07<00:00,  1.97it/s]
# EPOCH: 0006 	rain_loss: 1.5005
# 100%|██████████| 7/7 [3:16:41<00:00, 1685.91s/it]
# ---------- epoch6: Model Save ----------

# %% [markdown]
# #### inference

# %%
# !gdown 1UxILFtGRu8uWnkFKliUwrbKre_u84WvF -O trainable_weights0
# !gdown 1-4LS5WGhXkrkkThaEzGBCFVUZz8mZqa8 -O trainable_weights1
# !gdown 1-D6DX6pkUuWH5mpTsq-dyLUv6rdeYk3T -O trainable_weights2
# !gdown 1-Lb8oPWHfijBx0HtxmMGLq4UNfw4sekr -O trainable_weights3
# !gdown 1-MLqlovIk4GGsORHiQbJdhg-cgqdoLbt -O trainable_weights4

# %%
for i in range(3, 5):
    model = Decoder(cfg).to(device)
    model.load_state_dict(torch.load(f'/content/trainable_weights{i}', map_location=device), strict=False)
    print(f'---------- trainable weights {i} is using ----------')

    evaluation_dict = {}
    for data in tqdm(val_loader):
        img = data['img'].to(device)
        file_name = data['filename']
        start_token = torch.tensor([[50256]]).to(device)

        for j in range(250):
            with torch.no_grad():
                pred = model(start_token, img)

            out_token = pred.argmax(dim=2)[0][-1]
            start_token = torch.cat((start_token, out_token.unsqueeze(0).unsqueeze(0)), dim=1)
            end_token = torch.sum(start_token[0] == 50256).item()
            if end_token == 2:
                pred_token = start_token[start_token != 50256]
                pred_token = pred_token.tolist()
                pred_caption = encoding.decode(pred_token)
                break

        evaluation_dict[file_name[0]] = pred_caption
        print('\n', 'file name: ', file_name[0], '\caption: ', evaluation_dict[file_name[0]])

    json_string = json.dumps(evaluation_dict, indent=2)  # The indent parameter is optional and adds indentation for better readability
    with open(f'/content/drive/MyDrive/NTU_DLCV/Hw3/p2_output_large/large_epoch{i}_output.json', 'w') as json_file:
        json_file.write(json_string)
    print(f'---------- Epoch{i} large params Saved ----------')
